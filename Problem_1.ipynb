# %% [markdown]
# # Problem 1: Language Modeling with RNNs
# * <b>Learning Objective:</b> In this problem, you are going to implement simple recurrent neural networks to deeply understand how RNNs works.
# * <b>Provided Code:</b> We provide the skeletons of classes you need to complete. Forward checking and gradient checkings are provided for verifying your implementation as well.
# * <b>TODOs:</b> you will firstly implement a vanilla RNN to get warm up, and then implement an LSTM to train a model that can generate text using your own text source (novel, lyrics etc).

# %%
from lib.rnn import *
from lib.layer_utils import *
from lib.grad_check import *
from lib.optim import *
from lib.train import *
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Recurrent Neural Networks
# We will use recurrent neural network (RNN) language models for text generation.
#
# Please complete the TODOs in the function `VanillaRNN` of the file `lib/layer_utils.py` which should contain implementations of different layer types that are needed for recurrent neural networks.
#
# And then, complete the TODOs in the file `lib/rnn.py` which uses these layers to implement an text generation model.

# %% [markdown]
# # Vanilla RNN: step forward
# Open the file `lib/layer_utils.py`. Implement the forward and backward passes for different types of layers that are commonly used in recurrent neural networks.
#
# First complete the implementation of the function `step_forward` which implements the forward pass for a single timestep of a vanilla recurrent neural network.
#
# After doing so run the following code. You should see errors less than 1e-8.

# %%
# %reload_ext autoreload

N, D, H = 3, 10, 4

rnn = VanillaRNN(D, H, init_scale=0.02, name="rnn_test")
x = np.linspace(-0.4, 0.7, num=N*D).reshape(N, D)
prev_h = np.linspace(-0.2, 0.5, num=N*H).reshape(N, H)

rnn.params[rnn.wx_name] = np.linspace(-0.1, 0.9, num=D*H).reshape(D, H)
rnn.params[rnn.wh_name] = np.linspace(-0.3, 0.7, num=H*H).reshape(H, H)
rnn.params[rnn.b_name] = np.linspace(-0.2, 0.4, num=H)

next_h, _ = rnn.step_forward(x, prev_h)
expected_next_h = np.asarray([
  [-0.58172089, -0.50182032, -0.41232771, -0.31410098],
  [ 0.66854692,  0.79562378,  0.87755553,  0.92795967],
  [ 0.97934501,  0.99144213,  0.99646691,  0.99854353]])

print('next_h error: ', rel_error(expected_next_h, next_h))
# Out:
# next_h error:  6.292421426471037e-09

# %% [markdown]
# # Vanilla RNN: step backward
# In the `VanillaRNN` class in the file `lib/layer_utils.py` complete the `step_backward` function.
#
# After doing so run the following to numerically gradient check the implementation. You should see errors less than `1e-8`.

# %%
# %reload_ext autoreload

np.random.seed(231)
N, D, H = 4, 5, 6

rnn = VanillaRNN(D, H, init_scale=0.02, name="rnn_test")

x = np.random.randn(N, D)
h = np.random.randn(N, H)
Wx = np.random.randn(D, H)
Wh = np.random.randn(H, H)
b = np.random.randn(H)

rnn.params[rnn.wx_name] = Wx
rnn.params[rnn.wh_name] = Wh
rnn.params[rnn.b_name] = b

out, meta = rnn.step_forward(x, h)

dnext_h = np.random.randn(*out.shape)

dx_num = eval_numerical_gradient_array(lambda x: rnn.step_forward(x, h)[0], x, dnext_h)
dprev_h_num = eval_numerical_gradient_array(lambda h: rnn.step_forward(x, h)[0], h, dnext_h)
dWx_num = eval_numerical_gradient_array(lambda Wx: rnn.step_forward(x, h)[0], Wx, dnext_h)
dWh_num = eval_numerical_gradient_array(lambda Wh: rnn.step_forward(x, h)[0], Wh, dnext_h)
db_num = eval_numerical_gradient_array(lambda b: rnn.step_forward(x, h)[0], b, dnext_h)

dx, dprev_h, dWx, dWh, db = rnn.step_backward(dnext_h, meta)

print('dx error: ', rel_error(dx_num, dx))
print('dprev_h error: ', rel_error(dprev_h_num, dprev_h))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  9.956042620801298e-10
# dprev_h error:  4.095486732092561e-10
# dWx error:  1.264200416692046e-10
# dWh error:  3.1863456358952086e-10
# db error:  1.7439260972737542e-11

# %% [markdown]
# # Vanilla RNN: forward
# Now that you have  completed the forward and backward passes for a single timestep of a vanilla RNN, you will see how they are combined to implement a RNN that process an entire sequence of data.
#
# In the `VanillaRNN` class in the file `lib/layer_utils.py`, complete the function `forward`. This is implemented using the `step_forward` function that you defined above.
#
# After doing so run the following to check the implementation. You should see errors less than `1e-7`.

# %%
# %reload_ext autoreload

N, T, D, H = 2, 3, 4, 5

rnn = VanillaRNN(D, H, init_scale=0.02, name="rnn_test")

x = np.linspace(-0.1, 0.3, num=N*T*D).reshape(N, T, D)
h0 = np.linspace(-0.3, 0.1, num=N*H).reshape(N, H)
Wx = np.linspace(-0.2, 0.4, num=D*H).reshape(D, H)
Wh = np.linspace(-0.4, 0.1, num=H*H).reshape(H, H)
b = np.linspace(-0.7, 0.1, num=H)

rnn.params[rnn.wx_name] = Wx
rnn.params[rnn.wh_name] = Wh
rnn.params[rnn.b_name] = b

h = rnn.forward(x, h0)
expected_h = np.asarray([
  [
    [-0.42070749, -0.27279261, -0.11074945,  0.05740409,  0.22236251],
    [-0.39525808, -0.22554661, -0.0409454,   0.14649412,  0.32397316],
    [-0.42305111, -0.24223728, -0.04287027,  0.15997045,  0.35014525],
  ],
  [
    [-0.55857474, -0.39065825, -0.19198182,  0.02378408,  0.23735671],
    [-0.27150199, -0.07088804,  0.13562939,  0.33099728,  0.50158768],
    [-0.51014825, -0.30524429, -0.06755202,  0.17806392,  0.40333043]]])
print('h error: ', rel_error(expected_h, h))
# Out:
# h error:  7.728466151011529e-08

# %% [markdown]
# # Vanilla RNN: backward
# In the file `lib/layer_utils.py`, complete the backward pass for a vanilla RNN in the function `backward` in the `VanillaRNN` class. This runs back-propagation over the entire sequence, calling into the `step_backward` function defined above.
#
# You should see errors less than 5e-7.

# %%
# %reload_ext autoreload

np.random.seed(231)

N, D, T, H = 2, 3, 10, 5

rnn = VanillaRNN(D, H, init_scale=0.02, name="rnn_test")

x = np.random.randn(N, T, D)
h0 = np.random.randn(N, H)
Wx = np.random.randn(D, H)
Wh = np.random.randn(H, H)
b = np.random.randn(H)

rnn.params[rnn.wx_name] = Wx
rnn.params[rnn.wh_name] = Wh
rnn.params[rnn.b_name] = b

out = rnn.forward(x, h0)

dout = np.random.randn(*out.shape)

dx, dh0 = rnn.backward(dout)

dx_num = eval_numerical_gradient_array(lambda x: rnn.forward(x, h0), x, dout)
dh0_num = eval_numerical_gradient_array(lambda h0: rnn.forward(x, h0), h0, dout)
dWx_num = eval_numerical_gradient_array(lambda Wx: rnn.forward(x, h0), Wx, dout)
dWh_num = eval_numerical_gradient_array(lambda Wh: rnn.forward(x, h0), Wh, dout)
db_num = eval_numerical_gradient_array(lambda b: rnn.forward(x, h0), b, dout)

dWx = rnn.grads[rnn.wx_name]
dWh = rnn.grads[rnn.wh_name]
db = rnn.grads[rnn.b_name]

print('dx error: ', rel_error(dx_num, dx))
print('dh0 error: ', rel_error(dh0_num, dh0))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  2.3400101921142e-08
# dh0 error:  7.92260060756607e-10
# dWx error:  2.0884174065278893e-08
# dWh error:  1.7515369588373917e-08
# db error:  2.859395613678709e-10

# %% [markdown]
# # Word embedding: forward
# In deep learning systems, we commonly represent words using vectors. Each word of the vocabulary will be associated with a vector, and these vectors will be learned jointly with the rest of the system.
#
# In the file `lib/layer_utils.py`, implement the function `forward` in the `word_embedding` class to convert words (represented by integers) into vectors. Run the following to check the implementation. You should see error around `1e-8`.

# %%
# %reload_ext autoreload

N, T, V, D = 2, 4, 5, 3

we = word_embedding(V, D, name="we")

x = np.asarray([[0, 3, 1, 2], [2, 1, 0, 3]])
W = np.linspace(0, 1, num=V*D).reshape(V, D)

we.params[we.w_name] = W

out = we.forward(x)
expected_out = np.asarray([
 [[ 0.,          0.07142857,  0.14285714],
  [ 0.64285714,  0.71428571,  0.78571429],
  [ 0.21428571,  0.28571429,  0.35714286],
  [ 0.42857143,  0.5,         0.57142857]],
 [[ 0.42857143,  0.5,         0.57142857],
  [ 0.21428571,  0.28571429,  0.35714286],
  [ 0.,          0.07142857,  0.14285714],
  [ 0.64285714,  0.71428571,  0.78571429]]])

print('out error: ', rel_error(expected_out, out))
# Out:
# out error:  1.0000000094736443e-08

# %% [markdown]
# # Word embedding: backward
# Implement the backward pass for the word embedding function in the function `backward` in the `word_embedding` class. After doing so run the following to numerically gradient check your implementation. You should see errors less than `1e-11`.

# %%
# %reload_ext autoreload

np.random.seed(231)

N, T, V, D = 50, 3, 5, 6

we = word_embedding(V, D, name="we")

x = np.random.randint(V, size=(N, T))
W = np.random.randn(V, D)

we.params[we.w_name] = W

out = we.forward(x)
dout = np.random.randn(*out.shape)
we.backward(dout)

dW = we.grads[we.w_name]

f = lambda W: we.forward(x)
dW_num = eval_numerical_gradient_array(f, W, dout)

print('dW error: ', rel_error(dW, dW_num))
# Out:
# dW error:  3.2759440934795915e-12

# %% [markdown]
# # Temporal Fully Connected layer
# At every timestep we use an affine function to transform the RNN hidden vector at that timestep into scores for each word in the vocabulary. Because this is very similar to the fully connected layer that you implemented in assignment 1, we have provided this function for you in the `forward` and `backward` functions in the file `lib/layer_util.py`. Run the following to perform numeric gradient checking on the implementation. You should see errors less than 1e-9.

# %%
# %reload_ext autoreload

np.random.seed(231)

# Gradient check for temporal affine layer
N, T, D, M = 2, 3, 4, 5

t_fc = temporal_fc(D, M, init_scale=0.02, name='test_t_fc')

x = np.random.randn(N, T, D)
w = np.random.randn(D, M)
b = np.random.randn(M)

t_fc.params[t_fc.w_name] = w
t_fc.params[t_fc.b_name] = b

out = t_fc.forward(x)

dout = np.random.randn(*out.shape)

dx_num = eval_numerical_gradient_array(lambda x: t_fc.forward(x), x, dout)
dw_num = eval_numerical_gradient_array(lambda w: t_fc.forward(x), w, dout)
db_num = eval_numerical_gradient_array(lambda b: t_fc.forward(x), b, dout)

dx = t_fc.backward(dout)
dw = t_fc.grads[t_fc.w_name]
db = t_fc.grads[t_fc.b_name]

print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  3.9444359020219314e-10
# dw error:  5.0306285137140206e-11
# db error:  1.1455396263586309e-11

# %% [markdown]
# # Temporal Softmax loss
# In an RNN language model, at every timestep we produce a score for each word in the vocabulary. We know the ground-truth word at each timestep, so we use a softmax loss function to compute loss and gradient at each timestep. We sum the losses over time and average them over the minibatch.
#
# We provide this loss function for you; look at the `temporal_softmax_loss` function in the file `lib/layer_utils.py`.
#
# Run the following cell to sanity check the loss and perform numeric gradient checking on the function. You should see an error for dx less than 1e-7.

# %%
# %reload_ext autoreload

loss_func = temporal_softmax_loss()

# Sanity check for temporal softmax loss
N, T, V = 100, 1, 10

def check_loss(N, T, V, p):
    x = 0.001 * np.random.randn(N, T, V)
    y = np.random.randint(V, size=(N, T))
    mask = np.random.rand(N, T) <= p
    print(loss_func.forward(x, y, mask))
  
check_loss(100, 1, 10, 1.0)   # Should be about 2.3
check_loss(100, 10, 10, 1.0)  # Should be about 23
check_loss(5000, 10, 10, 0.1) # Should be about 2.3

# Gradient check for temporal softmax loss
N, T, V = 7, 8, 9

x = np.random.randn(N, T, V)
y = np.random.randint(V, size=(N, T))
mask = (np.random.rand(N, T) > 0.5)

loss = loss_func.forward(x, y, mask)
dx = loss_func.backward()

dx_num = eval_numerical_gradient(lambda x: loss_func.forward(x, y, mask), x, verbose=False)

print('dx error: ', rel_error(dx, dx_num))
# Out:
# 2.3026547279318357
# 23.026307039328714
# 2.2989009292538665
# dx error:  4.0464746298031226e-08

# %% [markdown]
# # RNN for language modeling
# Now that you have the necessary layers, you can combine them to build a language modeling model. Open the file `lib/rnn.py` and look at the `TestRNN` class.
#
# Check the forward and backward pass of the model in the `loss` function. For now you only see the implementation of the case where `cell_type='rnn'` for vanilla RNNs; you will implement the LSTM case later. After doing so, run the following to check the forward pass using a small test case; you should see error less than `1e-10`.

# %%
# %reload_ext autoreload

N, D, H = 10, 20, 40
V = 4
T = 13

model = TestRNN(D, H, cell_type='rnn')
loss_func = temporal_softmax_loss()

# Set all model parameters to fixed values
for k, v in model.params.items():
    model.params[k] = np.linspace(-1.4, 1.3, num=v.size).reshape(*v.shape)
model.assign_params()

features = np.linspace(-1.5, 0.3, num=(N * D * T)).reshape(N, T, D)
h0 = np.linspace(-1.5, 0.5, num=(N*H)).reshape(N, H)
labels = (np.arange(N * T) % V).reshape(N, T)

pred = model.forward(features, h0)

# You'll need this
mask = np.ones((N, T))

loss = loss_func.forward(pred, labels, mask)
dLoss = loss_func.backward()

expected_loss = 51.0949189134

print('loss: ', loss)
print('expected loss: ', expected_loss)
print('difference: ', abs(loss - expected_loss))
# Out:
# loss:  51.094918913361184
# expected loss:  51.0949189134
# difference:  3.881694965457427e-11

# %% [markdown]
# Run the following cell to perform numeric gradient checking on the `TestRNN` class; you should errors around `1e-7` or less.

# %%
# %reload_ext autoreload

np.random.seed(231)

batch_size = 2
timesteps = 3
input_dim = 4
hidden_dim = 6
label_size = 4

labels = np.random.randint(label_size, size=(batch_size, timesteps))
features = np.random.randn(batch_size, timesteps, input_dim)
h0 = np.random.randn(batch_size, hidden_dim)

model = TestRNN(input_dim, hidden_dim, cell_type='rnn')
loss_func = temporal_softmax_loss()

pred = model.forward(features, h0)

# You'll need this
mask = np.ones((batch_size, timesteps))

loss = loss_func.forward(pred, labels, mask)
dLoss = loss_func.backward()

dout, dh0 = model.backward(dLoss)

grads = model.grads

for param_name in sorted(grads):
    
    f = lambda _: loss_func.forward(model.forward(features, h0), labels, mask)
    param_grad_num = eval_numerical_gradient(f, model.params[param_name], verbose=False, h=1e-6)
    e = rel_error(param_grad_num, grads[param_name])
    print('%s relative error: %e' % (param_name, e))
# Out:
# vanilla_rnn_b relative error: 9.451394e-08
# vanilla_rnn_wh relative error: 3.221744e-08
# vanilla_rnn_wx relative error: 9.508480e-08

# %% [markdown]
# # LSTM
# Vanilla RNNs can be tough to train on long sequences due to vanishing and exploding gradiants. LSTMs solve this problem by replacing the simple update rule of the vanilla RNN with a gating mechanism as follows.
#
# Similar to the vanilla RNN, at each timestep we receive an input $x_t\\in\\mathbb{R}^D$ and the previous hidden state $h_{t-1}\\in\\mathbb{R}^H$; what is different in the LSTM is to maintain an $H$-dimensional *cell state*, so we also receive the previous cell state $c_{t-1}\\in\\mathbb{R}^H$. The learnable parameters of the LSTM are an *input-to-hidden* matrix $W_x\\in\\mathbb{R}^{4H\\times D}$, a *hidden-to-hidden* matrix $W_h\\in\\mathbb{R}^{4H\\times H}$ and a *bias vector* $b\\in\\mathbb{R}^{4H}$.
#
# At each timestep we first compute an *activation vector* $a\in\mathbb{R}^{4H}$ as $a=W_xx_t + W_hh_{t-1}+b$. We then divide this into four vectors $a_i,a_f,a_o,a_g\in\mathbb{R}^H$ where $a_i$ consists of the first $H$ elements of $a$, $a_f$ is the next $H$ elements of $a$, etc. We then compute the *input gate* $g\in\mathbb{R}^H$, *forget gate* $f\in\mathbb{R}^H$, *output gate* $o\in\mathbb{R}^H$ and *gate gate* $g\in\mathbb{R}^H$ as
#
# $$
# \begin{align*}
# i = \sigma(a_i) \hspace{2pc}
# f = \sigma(a_f) \hspace{2pc}
# o = \sigma(a_o) \hspace{2pc}
# g = \tanh(a_g)
# \end{align*}
# $$
#
# where $\sigma$ is the sigmoid function and $\tanh$ is the hyperbolic tangent, both applied elementwise.
#
# Finally we compute the next cell state $c_t$ and next hidden state $h_t$ as
#
# $$
# c_{t} = f\odot c_{t-1} + i\odot g \hspace{4pc}
# h_t = o\odot\tanh(c_t)
# $$
#
# where $\odot$ is the elementwise product of vectors.
#
# In the rest of the notebook we will implement the LSTM update rule and apply it to the text generation task.
#
# In the code, we assume that data is stored in batches so that $X_t \in \mathbb{R}^{N\times D}$, and will work with *transposed* versions of the parameters: $W_x \in \mathbb{R}^{D \times 4H}$, $W_h \in \mathbb{R}^{H\times 4H}$ so that activations $A \in \mathbb{R}^{N\times 4H}$ can be computed efficiently as $A = X_t W_x + H_{t-1} W_h$

# %% [markdown]
# # LSTM: step forward
# Implement the forward pass for a single timestep of an LSTM in the `step_forward` function in the file `lib/layer_utils.py`. This should be similar to the `step_forward` function that you implemented above, but using the LSTM update rule instead.
#
# Once you are done, run the following to perform a simple test of your implementation. You should see errors around `1e-8` or less.

# %%
# %reload_ext autoreload

N, D, H = 3, 4, 5

lstm = LSTM(D, H, init_scale=0.02, name='test_lstm')

x = np.linspace(-0.4, 1.2, num=N*D).reshape(N, D)
prev_h = np.linspace(-0.3, 0.7, num=N*H).reshape(N, H)
prev_c = np.linspace(-0.4, 0.9, num=N*H).reshape(N, H)
Wx = np.linspace(-2.1, 1.3, num=4*D*H).reshape(D, 4 * H)
Wh = np.linspace(-0.7, 2.2, num=4*H*H).reshape(H, 4 * H)
b = np.linspace(0.3, 0.7, num=4*H)

lstm.params[lstm.wx_name] = Wx
lstm.params[lstm.wh_name] = Wh
lstm.params[lstm.b_name] = b

next_h, next_c, cache = lstm.step_forward(x, prev_h, prev_c)

expected_next_h = np.asarray([
    [ 0.24635157,  0.28610883,  0.32240467,  0.35525807,  0.38474904],
    [ 0.49223563,  0.55611431,  0.61507696,  0.66844003,  0.7159181 ],
    [ 0.56735664,  0.66310127,  0.74419266,  0.80889665,  0.858299  ]])
expected_next_c = np.asarray([
    [ 0.32986176,  0.39145139,  0.451556,    0.51014116,  0.56717407],
    [ 0.66382255,  0.76674007,  0.87195994,  0.97902709,  1.08751345],
    [ 0.74192008,  0.90592151,  1.07717006,  1.25120233,  1.42395676]])

print('next_h error: ', rel_error(expected_next_h, next_h))
print('next_c error: ', rel_error(expected_next_c, next_c))
# Out:
# next_h error:  5.7054130404539434e-09
# next_c error:  5.8143123088804145e-09

# %% [markdown]
# # LSTM: step backward
# Implement the backward pass for a single LSTM timestep in the function `step_backward` in the file `lib/layer_utils.py`. Once you are done, run the following to perform numeric gradient checking on your implementation. You should see errors around `1e-6` or less.

# %%
# %reload_ext autoreload

np.random.seed(231)

N, D, H = 4, 5, 6

lstm = LSTM(D, H, init_scale=0.02, name='test_lstm')

x = np.random.randn(N, D)
prev_h = np.random.randn(N, H)
prev_c = np.random.randn(N, H)
Wx = np.random.randn(D, 4 * H)
Wh = np.random.randn(H, 4 * H)
b = np.random.randn(4 * H)

lstm.params[lstm.wx_name] = Wx
lstm.params[lstm.wh_name] = Wh
lstm.params[lstm.b_name] = b

next_h, next_c, cache = lstm.step_forward(x, prev_h, prev_c)

dnext_h = np.random.randn(*next_h.shape)
dnext_c = np.random.randn(*next_c.shape)

fx_h = lambda x: lstm.step_forward(x, prev_h, prev_c)[0]
fh_h = lambda h: lstm.step_forward(x, prev_h, prev_c)[0]
fc_h = lambda c: lstm.step_forward(x, prev_h, prev_c)[0]
fWx_h = lambda Wx: lstm.step_forward(x, prev_h, prev_c)[0]
fWh_h = lambda Wh: lstm.step_forward(x, prev_h, prev_c)[0]
fb_h = lambda b: lstm.step_forward(x, prev_h, prev_c)[0]

fx_c = lambda x: lstm.step_forward(x, prev_h, prev_c)[1]
fh_c = lambda h: lstm.step_forward(x, prev_h, prev_c)[1]
fc_c = lambda c: lstm.step_forward(x, prev_h, prev_c)[1]
fWx_c = lambda Wx: lstm.step_forward(x, prev_h, prev_c)[1]
fWh_c = lambda Wh: lstm.step_forward(x, prev_h, prev_c)[1]
fb_c = lambda b: lstm.step_forward(x, prev_h, prev_c)[1]

num_grad = eval_numerical_gradient_array

dx_num = num_grad(fx_h, x, dnext_h) + num_grad(fx_c, x, dnext_c)
dh_num = num_grad(fh_h, prev_h, dnext_h) + num_grad(fh_c, prev_h, dnext_c)
dc_num = num_grad(fc_h, prev_c, dnext_h) + num_grad(fc_c, prev_c, dnext_c)
dWx_num = num_grad(fWx_h, Wx, dnext_h) + num_grad(fWx_c, Wx, dnext_c)
dWh_num = num_grad(fWh_h, Wh, dnext_h) + num_grad(fWh_c, Wh, dnext_c)
db_num = num_grad(fb_h, b, dnext_h) + num_grad(fb_c, b, dnext_c)

dx, dh, dc, dWx, dWh, db = lstm.step_backward(dnext_h, dnext_c, cache)

print('dx error: ', rel_error(dx_num, dx))
print('dh error: ', rel_error(dh_num, dh))
print('dc error: ', rel_error(dc_num, dc))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  9.685574456833491e-10
# dh error:  8.734650691607799e-09
# dc error:  1.0127281785475644e-08
# dWx error:  1.8944292139281904e-07
# dWh error:  1.4617529136041527e-07
# db error:  1.867169717722288e-08

# %% [markdown]
# # LSTM: forward
# In the class `lstm` in the file `lib/layer_utils.py`, implement the `forward` function to run an LSTM forward on an entire timeseries of data.
#
# When you are done, run the following to check your implementation. You should see an error around `1e-7`.

# %%
# %reload_ext autoreload

N, D, H, T = 2, 5, 4, 3

lstm = LSTM(D, H, init_scale=0.02, name='test_lstm')

x = np.linspace(-0.4, 0.6, num=N*T*D).reshape(N, T, D)
h0 = np.linspace(-0.4, 0.8, num=N*H).reshape(N, H)
Wx = np.linspace(-0.2, 0.9, num=4*D*H).reshape(D, 4 * H)
Wh = np.linspace(-0.3, 0.6, num=4*H*H).reshape(H, 4 * H)
b = np.linspace(0.2, 0.7, num=4*H)

lstm.params[lstm.wx_name] = Wx
lstm.params[lstm.wh_name] = Wh
lstm.params[lstm.b_name] = b

h = lstm.forward(x, h0)

expected_h = np.asarray([
 [[ 0.01764008,  0.01823233,  0.01882671,  0.0194232 ],
  [ 0.11287491,  0.12146228,  0.13018446,  0.13902939],
  [ 0.31358768,  0.33338627,  0.35304453,  0.37250975]],
 [[ 0.45767879,  0.4761092,   0.4936887,   0.51041945],
  [ 0.6704845,   0.69350089,  0.71486014,  0.7346449 ],
  [ 0.81733511,  0.83677871,  0.85403753,  0.86935314]]])

print('h error: ', rel_error(expected_h, h))
# Out:
# h error:  8.610537452106624e-08

# %% [markdown]
# # LSTM: backward
# Implement the backward pass for an LSTM over an entire timeseries of data in the function `backward` in the `lstm` class in the file `lib/layer_utils.py`. When you are done, run the following to perform numeric gradient checking on your implementation. You should see errors around `1e-7` or less.

# %%
# %reload_ext autoreload

np.random.seed(231)

N, D, T, H = 2, 3, 10, 6

lstm = LSTM(D, H, init_scale=0.02, name='test_lstm')

x = np.random.randn(N, T, D)
h0 = np.random.randn(N, H)
Wx = np.random.randn(D, 4 * H)
Wh = np.random.randn(H, 4 * H)
b = np.random.randn(4 * H)

lstm.params[lstm.wx_name] = Wx
lstm.params[lstm.wh_name] = Wh
lstm.params[lstm.b_name] = b

out = lstm.forward(x, h0)

dout = np.random.randn(*out.shape)

dx, dh0 = lstm.backward(dout)
dWx = lstm.grads[lstm.wx_name] 
dWh = lstm.grads[lstm.wh_name]
db = lstm.grads[lstm.b_name]

dx_num = eval_numerical_gradient_array(lambda x: lstm.forward(x, h0), x, dout)
dh0_num = eval_numerical_gradient_array(lambda h0: lstm.forward(x, h0), h0, dout)
dWx_num = eval_numerical_gradient_array(lambda Wx: lstm.forward(x, h0), Wx, dout)
dWh_num = eval_numerical_gradient_array(lambda Wh: lstm.forward(x, h0), Wh, dout)
db_num = eval_numerical_gradient_array(lambda b: lstm.forward(x, h0), b, dout)

print('dx error: ', rel_error(dx_num, dx))
print('dh0 error: ', rel_error(dh0_num, dh0))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  1.4937999827177003e-09
# dh0 error:  4.0382962059143766e-10
# dWx error:  8.724595165492287e-09
# dWh error:  1.0328639977500716e-07
# db error:  4.115531506589073e-10

# %% [markdown]
# # LSTM model
#
# Now that you have implemented an LSTM, update the initialization of the `TestRNN` class in the file `lib/rnn.py` to handle the case where `self.cell_type` is `lstm`. This should require adding only one line of code.
#
# Once you have done so, run the following to check your implementation. You should see a difference of less than `1e-10`.

# %%
# %reload_ext autoreload

N, D, H = 10, 20, 40
V = 4
T = 13

model = TestRNN(D, H, cell_type='lstm')
loss_func = temporal_softmax_loss()

# Set all model parameters to fixed values
for k, v in model.params.items():
    model.params[k] = np.linspace(-1.4, 1.3, num=v.size).reshape(*v.shape)
model.assign_params()

features = np.linspace(-1.5, 0.3, num=(N * D * T)).reshape(N, T, D)
h0 = np.linspace(-1.5, 0.5, num=(N*H)).reshape(N, H)
labels = (np.arange(N * T) % V).reshape(N, T)

pred = model.forward(features, h0)

# You'll need this
mask = np.ones((N, T))

loss = loss_func.forward(pred, labels, mask)
dLoss = loss_func.backward()

expected_loss = 49.2140256354

print('loss: ', loss)
print('expected loss: ', expected_loss)
print('difference: ', abs(loss - expected_loss))
# Out:
# loss:  49.21402563544293
# expected loss:  49.2140256354
# difference:  4.293099209462525e-11

# %% [markdown]
# # Let's have some fun!!
#
# Now you have everything you need for language modeling. You will work on text generation using RNNs from any text source (novel, lyrics).
#
# The network is trained to predict what word is coming next given a previous word. Once you train the model, by looping the network, you can keep generating a new text which is mimicing the original text source.
#
# We will use one of the most frequently downloaded e-books, Alice's Adventures in Wonderland, from Project Gutenberg, where the original link can be found [here](https://www.gutenberg.org/ebooks/11).
#
# We extracted only the first chapter for the resources saving.

# %%
# %reload_ext autoreload

input_file = open("data/alice.txt", "r", encoding='utf-8')
input_text = input_file.readlines()
input_text = ''.join(input_text)

# %% [markdown]
# simply run the following code to construct training dataset<br />

# %%
# %reload_ext autoreload

import re

text = re.split(' |\n',input_text.lower()) # all words are converted into lower case
outputSize = len(text)
word_list = list(set(text))
dataSize = len(word_list)
output = np.zeros(outputSize)
for i in range(0, outputSize):
    index = np.where(np.asarray(word_list) == text[i])
    output[i] = index[0]
data_labels = output.astype(np.int)
gt_labels = data_labels[1:]
data_labels = data_labels[:-1]

print('Input text size: %s' % outputSize)
print('Input word number: %s' % dataSize)
# Out:
# Input text size: 2170
# Input word number: 778

# %% [markdown]
# We defined a LanguageModelRNN class for you to fill in the TODO block in rnn.py.
# * Here design a recurrent neutral network consisting of a word_embedding layer, recurrent unit, and temporal fully connected layers so that they match the provided dimensions.
# * Please read the train.py under lib directory carefully and complete the TODO blocks in the train_net function first.

# %%
# %reload_ext autoreload

# you can change the following parameters.
D = 10 # input dimention
H = 20 # hidden space dimention
T = 50 # timesteps
N = 10 # batch size
max_epoch = 50 # max epoch size

loss_func = temporal_softmax_loss()
# you can change the cell_type between 'rnn' and 'lstm'.
model = LanguageModelRNN(dataSize, D, H, cell_type='lstm')
optimizer = Adam(model, 5e-4)

data = { 'data_train': data_labels, 'labels_train': gt_labels }

results = train_net(data, model, loss_func, optimizer, timesteps=T, batch_size=N, max_epochs=max_epoch, verbose=True)
#  Acc ~59.6%
# Out:
# (Iteration 1 / 10800) loss: 332.84333329088423
# best performance 3.5961272475795294%
# (Epoch 1 / 50) Training Accuracy: 0.035961272475795295
# best performance 4.149377593360995%
# (Epoch 2 / 50) Training Accuracy: 0.04149377593360996
# (Iteration 501 / 10800) loss: 292.89147324277803
# best performance 4.195481788842784%
# (Epoch 3 / 50) Training Accuracy: 0.041954817888427844
# best performance 5.394190871369295%
# (Epoch 4 / 50) Training Accuracy: 0.05394190871369295
# (Iteration 1001 / 10800) loss: 278.109556460826
# best performance 5.809128630705394%
# (Epoch 5 / 50) Training Accuracy: 0.058091286307053944
# best performance 6.224066390041494%
# (Epoch 6 / 50) Training Accuracy: 0.06224066390041494
# (Iteration 1501 / 10800) loss: 258.8421935038658
# best performance 6.685108344859382%
# (Epoch 7 / 50) Training Accuracy: 0.06685108344859382
# best performance 7.699400645458737%
# (Epoch 8 / 50) Training Accuracy: 0.07699400645458737
# best performance 8.621484555094513%
# (Epoch 9 / 50) Training Accuracy: 0.08621484555094514
# (Iteration 2001 / 10800) loss: 245.62187995662725
# best performance 9.451360073766713%
# (Epoch 10 / 50) Training Accuracy: 0.09451360073766712
# best performance 10.972798524665745%
# (Epoch 11 / 50) Training Accuracy: 0.10972798524665744
# (Iteration 2501 / 10800) loss: 226.73301336959193
# best performance 11.295527893038267%
# (Epoch 12 / 50) Training Accuracy: 0.11295527893038267
# best performance 13.093591516828033%
# (Epoch 13 / 50) Training Accuracy: 0.13093591516828032
# (Iteration 3001 / 10800) loss: 216.67928047419764
# best performance 13.877362840018442%
# (Epoch 14 / 50) Training Accuracy: 0.13877362840018442
# best performance 14.707238358690642%
# (Epoch 15 / 50) Training Accuracy: 0.1470723835869064
# best performance 15.998155832180727%
# (Epoch 16 / 50) Training Accuracy: 0.15998155832180727
# (Iteration 3501 / 10800) loss: 211.7886019562201
# best performance 17.335177501152604%
# (Epoch 17 / 50) Training Accuracy: 0.17335177501152604
# best performance 18.39557399723375%
# (Epoch 18 / 50) Training Accuracy: 0.1839557399723375
# (Iteration 4001 / 10800) loss: 186.43793829064035
# best performance 20.009220839096358%
# (Epoch 19 / 50) Training Accuracy: 0.2000922083909636
# best performance 21.53065928999539%
# (Epoch 20 / 50) Training Accuracy: 0.2153065928999539
# (Iteration 4501 / 10800) loss: 179.47087037686234
# best performance 23.46703550023052%
# (Epoch 21 / 50) Training Accuracy: 0.2346703550023052
# best performance 25.357307514983862%
# (Epoch 22 / 50) Training Accuracy: 0.2535730751498386
# best performance 27.155371138773628%
# (Epoch 23 / 50) Training Accuracy: 0.27155371138773626
# (Iteration 5001 / 10800) loss: 160.07247157802053
# best performance 29.55278930382665%
# (Epoch 24 / 50) Training Accuracy: 0.2955278930382665
# best performance 31.489165514061778%
# (Epoch 25 / 50) Training Accuracy: 0.3148916551406178
# (Iteration 5501 / 10800) loss: 156.24008194494408
# best performance 33.84047948363301%
# (Epoch 26 / 50) Training Accuracy: 0.3384047948363301
# best performance 35.50023052097741%
# (Epoch 27 / 50) Training Accuracy: 0.3550023052097741
# (Iteration 6001 / 10800) loss: 146.3890930157803
# best performance 37.25218994928539%
# (Epoch 28 / 50) Training Accuracy: 0.37252189949285386
# best performance 39.23467035500231%
# (Epoch 29 / 50) Training Accuracy: 0.39234670355002305
# best performance 41.21715076071922%
# (Epoch 30 / 50) Training Accuracy: 0.41217150760719223
# (Iteration 6501 / 10800) loss: 131.57152646752795
# best performance 42.692485016136466%
# (Epoch 31 / 50) Training Accuracy: 0.42692485016136467
# best performance 44.12171507607192%
# (Epoch 32 / 50) Training Accuracy: 0.4412171507607192
# (Iteration 7001 / 10800) loss: 129.1277226085702
# best performance 45.13600737667128%
# (Epoch 33 / 50) Training Accuracy: 0.4513600737667128
# best performance 46.703550023052095%
# (Epoch 34 / 50) Training Accuracy: 0.467035500230521
# (Iteration 7501 / 10800) loss: 121.37985346314244
# best performance 47.671738128169665%
# (Epoch 35 / 50) Training Accuracy: 0.47671738128169666
# best performance 48.77823881973259%
# (Epoch 36 / 50) Training Accuracy: 0.48778238819732594
# best performance 50.25357307514984%
# (Epoch 37 / 50) Training Accuracy: 0.5025357307514984
# (Iteration 8001 / 10800) loss: 118.63935853601701
# best performance 50.89903181189488%
# (Epoch 38 / 50) Training Accuracy: 0.5089903181189488
# best performance 51.82111572153067%
# (Epoch 39 / 50) Training Accuracy: 0.5182111572153066
# (Iteration 8501 / 10800) loss: 106.97239772387243
# best performance 52.88151221761181%
# (Epoch 40 / 50) Training Accuracy: 0.528815122176118
# best performance 53.619179345320426%
# (Epoch 41 / 50) Training Accuracy: 0.5361917934532042
# (Iteration 9001 / 10800) loss: 104.90856128333003
# best performance 53.988012909174735%
# (Epoch 42 / 50) Training Accuracy: 0.5398801290917473
# best performance 54.77178423236515%
# (Epoch 43 / 50) Training Accuracy: 0.5477178423236515
# (Iteration 9501 / 10800) loss: 96.33752903013313
# best performance 55.69386814200092%
# (Epoch 44 / 50) Training Accuracy: 0.5569386814200092
# best performance 56.24711848778239%
# (Epoch 45 / 50) Training Accuracy: 0.5624711848778239
# best performance 57.63024435223605%
# (Epoch 46 / 50) Training Accuracy: 0.5763024435223605
# (Iteration 10001 / 10800) loss: 94.23516584207263
# best performance 58.229598893499315%
# (Epoch 47 / 50) Training Accuracy: 0.5822959889349931
# best performance 58.64453665283541%
# (Epoch 48 / 50) Training Accuracy: 0.5864453665283541
# (Iteration 10501 / 10800) loss: 86.51575306503327
# best performance 59.289995389580454%
# (Epoch 49 / 50) Training Accuracy: 0.5928999538958045
# best performance 59.612724757952975%
# (Epoch 50 / 50) Training Accuracy: 0.5961272475795297

# %% [markdown]
# Simply run the following code block to check the loss and accuracy curve.

# %%
# %reload_ext autoreload

opt_params, loss_hist, train_acc_hist = results

# Plot the learning curves
plt.subplot(2, 1, 1)
plt.title('Training loss')
loss_hist_ = loss_hist[1::100] # sparse the curve a bit
plt.plot(loss_hist_, '-o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(train_acc_hist, '-o', label='Training')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)

plt.show()

# %% [markdown]
# Now you can generate a text using the trained model. You can start from a specific word in the original text, such as `she`.

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 15

idx = 0
# you also can start from specific word. 
# since the words are all converted into lower case
idx = int(np.where(np.asarray(word_list) == 'She'.lower())[0])

# sample from the trained model
words = model.sample(idx, text_length-1)

# convert indices into words
output = [ word_list[i] for i in words]
print(' '.join(output))
# Out:
# she was no longer to be two people! why, there’s hardly enough of them. however,

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 30

idx = 0
# you also can start from specific word. 
# since the words are all converted into lower case
idx = int(np.where(np.asarray(word_list) == 'She'.lower())[0])

# sample from the trained model
words = model.sample(idx, text_length-1)

# convert indices into words
output = [ word_list[i] for i in words]
print(' '.join(output))
# Out:
# she was no longer to be two people! why, there’s hardly enough of them. however, on the right word) ‘--but i shall have to be two people! why, there’s hardly

# %%
word_list
# Out:
# ['',
#  'day',
#  'small,',
#  'is',
#  'hanging',
#  'somebody,',
#  'through',
#  'trouble',
#  'left',
#  'nothing',
#  'know,’',
#  'showing',
#  'four',
#  'cats?’',
#  'taught',
#  'ate',
#  'never',
#  'gave',
#  'hurt,',
#  'holding',
#  'not’;',
#  'book',
#  'those',
#  'cake,',
#  'must',
#  'or',
#  'you',
#  'disagree',
#  'in',
#  'suddenly,',
#  'words',
#  'surprised',
#  'top',
#  'cried.',
#  'saw.',
#  'thought',
#  'antipathies,',
#  'long,',
#  'glass',
#  'way,',
#  'didn’t',
#  'australia?’',
#  'earth.',
#  'say,',
#  'candle.',
#  'forgotten',
#  'dark',
#  'same',
#  'a',
#  'eyes',
#  'really',
#  'of',
#  'now',
#  'tears',
#  'impossible.',
#  'could',
#  'dry',
#  'door;',
#  'pretending',
#  'knew',
#  'along',
#  'telescope!',
#  'leave',
#  'latitude',
#  'telescopes:',
#  'roast',
#  'wild',
#  'even',
#  'alice,)',
#  'she’ll',
#  'remember',
#  'overhead;',
#  'manage',
#  'glass,',
#  'had,',
#  'knowledge,',
#  'garden',
#  'reading,',
#  'certain',
#  'listening,',
#  'can',
#  'bottle',
#  'all',
#  'own',
#  'before',
#  'wander',
#  'alice;',
#  '(alice',
#  'grand',
#  'waistcoat-pocket,',
#  'matter',
#  'quite',
#  'hear',
#  'for',
#  'red-hot',
#  'pine-apple,',
#  'late',
#  'lamps',
#  'upon',
#  'stairs!',
#  'bleeds;',
#  'head',
#  '‘dinah’ll',
#  'conversations',
#  'rules',
#  'it',
#  'so',
#  'don’t',
#  'them:',
#  'suddenly',
#  '‘well!’',
#  'end!',
#  'bring',
#  'managed',
#  'nice',
#  'truth:',
#  'killing',
#  'it.',
#  'nor',
#  'whether',
#  'makes',
#  'lessons',
#  'three-legged',
#  'earth!',
#  'cupboards',
#  'drop',
#  'curiosity,',
#  'maps',
#  'down',
#  'out-of-the-way',
#  'twice',
#  'off',
#  'miss',
#  '(it',
#  'country',
#  'low',
#  'before,',
#  'saying',
#  'oh,',
#  'bit,',
#  'led',
#  'noticed',
#  'soon',
#  'that,',
#  '(which',
#  'flashed',
#  'field',
#  'eyes;',
#  'let',
#  'could,',
#  'somewhere',
#  'i’m',
#  '“poison”',
#  'because',
#  'no',
#  'toast,)',
#  'remarkable',
#  'one',
#  'people!',
#  'picking',
#  'came',
#  'feel',
#  'without',
#  'alice’s',
#  'this',
#  'on,',
#  'either',
#  'happened',
#  'slippery;',
#  'having',
#  'is,',
#  'them',
#  'saucer',
#  'mind',
#  'practice',
#  'put',
#  'who',
#  'wish',
#  'began',
#  'falling',
#  'now,’',
#  'brightened',
#  'great',
#  'she',
#  'over.',
#  'you’re',
#  'her.',
#  'crying',
#  'curious',
#  'seemed',
#  'looked',
#  'moment:',
#  '‘eat',
#  'hurrying',
#  'second',
#  'couldn’t',
#  'through,’',
#  'feeling!’',
#  'lovely',
#  'watch',
#  '‘oh',
#  'alice!',
#  'deep,',
#  'this,',
#  'taste',
#  'brave',
#  'ears',
#  'pretend',
#  'are',
#  'common',
#  'first,’',
#  'anything;',
#  'key',
#  'see,',
#  'seldom',
#  'me,’',
#  'marked',
#  'minute!’',
#  'off,',
#  'bat?’',
#  'the',
#  '(when',
#  'tumbling',
#  'sometimes,',
#  'straight',
#  'dreamy',
#  'once',
#  'cat.)',
#  'life',
#  'thing',
#  'down,',
#  'your',
#  'sort',
#  'shall',
#  'spoke--fancy',
#  'started',
#  'alas',
#  'centre',
#  'off.',
#  '[‘which',
#  'several',
#  'hot',
#  'time,',
#  'for,',
#  '‘drink',
#  'me!',
#  'lost:',
#  'dear!',
#  'afterwards,',
#  'other,',
#  'too',
#  'natural);',
#  'answer',
#  'ran',
#  'key,',
#  'rat-hole:',
#  'down.',
#  'high,',
#  'larger',
#  'its',
#  'fact,',
#  'coming',
#  'not',
#  'large,',
#  'fall',
#  'home!',
#  '(though',
#  'see:',
#  'time',
#  'wondering',
#  'unpleasant',
#  'passage',
#  'chapter',
#  'saw',
#  'fell',
#  'end,',
#  'reach',
#  'lately,',
#  'sharply;',
#  'use',
#  'book,’',
#  'shrink',
#  'person!’',
#  'golden',
#  '‘what',
#  'past',
#  'made',
#  'shutting',
#  '‘for',
#  'certainly',
#  'ever',
#  'filled',
#  'on',
#  'perhaps',
#  'afraid,',
#  'occurred',
#  'take',
#  '(dinah',
#  'flavour',
#  'remained',
#  'bats?',
#  'grow',
#  'sure,',
#  'jumped',
#  'should',
#  'actually',
#  'loveliest',
#  'hall,',
#  'else',
#  'sat',
#  'true.)',
#  'indeed:',
#  'creep',
#  'this;',
#  'wonder?’',
#  'shelves',
#  'somewhere.’',
#  'flowers',
#  'herself',
#  'knife,',
#  'sadly',
#  'way?’,',
#  '‘to',
#  'going',
#  'box',
#  'nervous',
#  'empty:',
#  'up,',
#  'things,',
#  'glass;',
#  'do:',
#  'distance--but',
#  'more',
#  'turkey,',
#  'they’ll',
#  'before,’',
#  'happen,',
#  'talking',
#  'it?)',
#  'eye',
#  'stupid',
#  'close',
#  '‘now,',
#  'said',
#  'currants.',
#  'begun',
#  'them.',
#  'said,',
#  'why,',
#  'hold',
#  'considering',
#  'zealand',
#  'dinah',
#  'best',
#  'that',
#  '‘in',
#  'high:',
#  'friends',
#  'had',
#  'to,',
#  'my',
#  'glad',
#  'air!',
#  'corner,',
#  'heads',
#  'itself,',
#  'still',
#  'child',
#  'ma’am,',
#  'beds',
#  'while,',
#  'that!’',
#  'making',
#  'letters.',
#  'earnestly,',
#  'do,',
#  'oh',
#  'about',
#  'sticks',
#  'happened,',
#  'which',
#  'it’s',
#  'seen:',
#  'turned',
#  'tried',
#  'ought',
#  'advise',
#  'it:',
#  'longed',
#  'garden,',
#  'bats',
#  'like',
#  'time?’',
#  'schoolroom,',
#  'though',
#  'there’s',
#  'what',
#  'eats',
#  'milk',
#  'be',
#  'i’ve',
#  'buttered',
#  'felt',
#  '(as',
#  'key;',
#  'pleasure',
#  'ignorant',
#  'indeed',
#  'almost',
#  'know.',
#  'finished',
#  'downward!',
#  'as',
#  'waiting',
#  'seen',
#  'table',
#  'it),',
#  'dull',
#  'asking!',
#  'deep',
#  'catch',
#  'worth',
#  'up',
#  'new',
#  'passed;',
#  'respectable',
#  '‘--yes,',
#  'was',
#  'good',
#  'belong',
#  'i’ll',
#  'toffee,',
#  'hurry.',
#  'candle',
#  'croquet',
#  'it’ll',
#  'rather',
#  'been',
#  'anything',
#  'first,',
#  'slowly,',
#  'word)',
#  'question,',
#  'sister',
#  'please,',
#  'finger',
#  'side',
#  'book-shelves;',
#  'me’',
#  'size',
#  'shut',
#  'to?’',
#  'usually',
#  'garden.',
#  'leaves,',
#  'well.',
#  'people',
#  'walking',
#  'row',
#  'burning',
#  'large',
#  'right',
#  'wonder',
#  'sleepy',
#  'look',
#  'doorway;',
#  'thing.',
#  'scolded',
#  'mice',
#  'fancy',
#  'much',
#  'plenty',
#  '‘without',
#  'dozing',
#  'getting',
#  'air,',
#  'any',
#  'peeped',
#  'think',
#  'under',
#  'well,',
#  'me',
#  'work,',
#  'there',
#  'opportunity',
#  'then?’',
#  'it,',
#  'but',
#  'say',
#  'game',
#  'cool',
#  'finding',
#  'deeply',
#  '‘and',
#  'anxiously',
#  'pictures',
#  'to',
#  'smaller,',
#  'find',
#  'back',
#  '‘which',
#  'simple',
#  'knelt',
#  'pegs.',
#  'legs',
#  '(she',
#  'make',
#  'wind,',
#  'except',
#  'walked',
#  'will',
#  'well',
#  'you,',
#  'bats,',
#  'waited',
#  'either,',
#  'hung',
#  'funny',
#  'disappointment',
#  'size:',
#  'happen',
#  'thump!',
#  'face',
#  'they',
#  'seem',
#  'way.',
#  'marmalade’,',
#  'whiskers,',
#  '‘but',
#  'half',
#  'then',
#  'would',
#  'other',
#  'rate',
#  'passage,',
#  'white',
#  '(for,',
#  'long;',
#  'severely',
#  'herself,',
#  'altogether,',
#  'care',
#  'daisies,',
#  'by',
#  'bit',
#  'sound',
#  'fitted!',
#  'hurried',
#  'curtseying',
#  'against',
#  'how',
#  'get',
#  'no,',
#  'first',
#  'alice',
#  'might',
#  'every',
#  'way',
#  'listen',
#  'people.',
#  'hand',
#  'curtsey',
#  'here',
#  'from',
#  'some',
#  'likely',
#  'idea',
#  'cherry-tart,',
#  'across',
#  'long',
#  'miles',
#  'pink',
#  'say.)',
#  'fountains,',
#  'solid',
#  'tiny',
#  'among',
#  'custard,',
#  '‘--but',
#  'written',
#  'set',
#  'an',
#  'dream',
#  'door',
#  'neck',
#  'have',
#  'behind',
#  'little',
#  'beautifully',
#  'see',
#  'fond',
#  'after',
#  'their',
#  'things',
#  'out,',
#  'label,',
#  'decided',
#  'took',
#  'if',
#  'burnt,',
#  'once;',
#  'possibly',
#  'bank,',
#  'however,',
#  'histories',
#  'round',
#  'paper',
#  'advice,',
#  'tell',
#  'think!’',
#  'conversations?’',
#  'further:',
#  'fallen',
#  'very',
#  'tunnel',
#  'were',
#  'mouse,',
#  'open',
#  'delight',
#  'later.',
#  'only',
#  '‘come,',
#  'happens!’',
#  'longer',
#  'sometimes',
#  'think--’',
#  'rabbit',
#  'her,',
#  'but,',
#  'wouldn’t',
#  'trying,',
#  'children',
#  'burn',
#  'trying',
#  'growing,',
#  'longitude',
#  'beginning',
#  'doors',
#  'moment',
#  'read',
#  'cake.',
#  'when',
#  'found',
#  'fifteen',
#  'wise',
#  'sooner',
#  'plainly',
#  'jar',
#  'curtain',
#  'ask',
#  'beasts',
#  'bat,',
#  'wondered',
#  'hope',
#  'enough',
#  'feet,',
#  'over',
#  'name',
#  'into',
#  'pop',
#  'daisy-chain',
#  '‘well,',
#  'thousand',
#  'locks',
#  'dipped',
#  'tea-time.',
#  'shoulders.',
#  'aloud.',
#  'got',
#  '‘poison,’',
#  'climb',
#  'expecting',
#  'cut',
#  '‘no,',
#  'sides',
#  'next.',
#  'such',
#  'hoping',
#  'presently',
#  'feet',
#  'telescope.’',
#  'way?',
#  'poker',
#  'dinah,',
#  'alice,',
#  'i',
#  'rabbit-hole',
#  'opened',
#  'bright',
#  'at',
#  'getting!’',
#  'begin.’',
#  'cheated',
#  'than',
#  'did',
#  '‘i',
#  'hedge.',
#  'table,',
#  'locked;',
#  '‘it',
#  'generally',
#  'cats',
#  '‘do',
#  'hall;',
#  'remembered',
#  'away',
#  'two',
#  'learnt',
#  'that;',
#  'poor',
#  'to-night,',
#  'round,',
#  '‘after',
#  'heap',
#  'eaten',
#  'stupid),',
#  '(and',
#  'middle,',
#  'small',
#  'printed',
#  'ventured',
#  '‘orange',
#  'sight,',
#  'as,',
#  'i.',
#  'nice,',
#  'roof.',
#  'out',
#  'blown',
#  'with',
#  'sitting',
#  'go',
#  'lock,',
#  'sleepy,',
#  'labelled',
#  'ten',
#  'fear',
#  'followed',
#  'house!’',
#  'larger,',
#  'walk',
#  'over)',
#  'again.',
#  'her',
#  'drink',
#  'near',
#  'do',
#  'few',
#  'world',
#  'many',
#  'went',
#  'lying',
#  'just',
#  'girl',
#  'door,',
#  'bats?’',
#  'tired',
#  'and',
#  'come',
#  'ask:',
#  'flame',
#  'stopping',
#  'lit',
#  'mixed',
#  'was,',
#  'fortunately',
#  'that’s',
#  'late!’',
#  'another',
#  'table:',
#  'minutes',
#  'inches',
#  'playing',
#  'eat',
#  'hardly',
#  'it,’',
#  'alas!',
#  'happens']

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 15

start_words = ['alice!', 'alice', 'alice,', 'brave', 'this', 'that', 'that,']

for start_word in start_words:
    idx = 0
    # you also can start from specific word. 
    # since the words are all converted into lower case
    idx = int(np.where(np.asarray(word_list) == start_word.lower())[0])

    # sample from the trained model
    words = model.sample(idx, text_length-1)

    # convert indices into words
    output = [ word_list[i] for i in words]
    print(' '.join(output))
# Out:
# alice! when she was not a moment to her great disappointment it was too slippery;
# alice was no longer to be two people! why, there’s hardly enough of them. however,
# alice, ‘and what latitude was, or longitude either, but were nice grand words like that!’
# brave they’ll all the little golden key, and when she was not a moment to
# this ‘for it was not a little door about fifteen inches high: she could not
# that she was not a moment to her great delight it was not a little
# that, if you see, as she was not a moment to her great delight it

# %%
# %reload_ext autoreload

# you can change the following parameters.
D = 10 # input dimention
H = 20 # hidden space dimention
T = 50 # timesteps
N = 10 # batch size
max_epoch = 50 # max epoch size

loss_func = temporal_softmax_loss()
# you can change the cell_type between 'rnn' and 'lstm'.
model = LanguageModelRNN(dataSize, D, H, cell_type='rnn')
optimizer = Adam(model, 5e-4)

data = { 'data_train': data_labels, 'labels_train': gt_labels }

results = train_net(data, model, loss_func, optimizer, timesteps=T, batch_size=N, max_epochs=max_epoch, verbose=True)
#  Acc ~60%

opt_params, loss_hist, train_acc_hist = results

# Plot the learning curves
plt.subplot(2, 1, 1)
plt.title('Training loss')
loss_hist_ = loss_hist[1::100] # sparse the curve a bit
plt.plot(loss_hist_, '-o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(train_acc_hist, '-o', label='Training')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)

plt.show()

# best performance 78.60 %
# Out:
# (Iteration 1 / 10800) loss: 332.8446521274492
# best performance 4.195481788842784%
# (Epoch 1 / 50) Training Accuracy: 0.041954817888427844
# (Epoch 2 / 50) Training Accuracy: 0.04103273397879207
# (Iteration 501 / 10800) loss: 280.3463836615295
# best performance 4.979253112033195%
# (Epoch 3 / 50) Training Accuracy: 0.04979253112033195
# best performance 7.745504840940526%
# (Epoch 4 / 50) Training Accuracy: 0.07745504840940526
# (Iteration 1001 / 10800) loss: 260.6739440039946
# best performance 8.990318118948824%
# (Epoch 5 / 50) Training Accuracy: 0.08990318118948824
# best performance 10.834485938220379%
# (Epoch 6 / 50) Training Accuracy: 0.10834485938220378
# (Iteration 1501 / 10800) loss: 218.94614677220233
# best performance 12.540341171046565%
# (Epoch 7 / 50) Training Accuracy: 0.12540341171046565
# best performance 15.214384508990317%
# (Epoch 8 / 50) Training Accuracy: 0.15214384508990317
# best performance 17.98063623789765%
# (Epoch 9 / 50) Training Accuracy: 0.1798063623789765
# (Iteration 2001 / 10800) loss: 202.08137137210957
# best performance 20.977408944213924%
# (Epoch 10 / 50) Training Accuracy: 0.20977408944213924
# best performance 24.619640387275243%
# (Epoch 11 / 50) Training Accuracy: 0.24619640387275243
# (Iteration 2501 / 10800) loss: 169.43916191101422
# best performance 28.21576763485477%
# (Epoch 12 / 50) Training Accuracy: 0.2821576763485477
# best performance 31.904103273397876%
# (Epoch 13 / 50) Training Accuracy: 0.31904103273397877
# (Iteration 3001 / 10800) loss: 151.17215629932514
# best performance 35.91516828031351%
# (Epoch 14 / 50) Training Accuracy: 0.3591516828031351
# best performance 38.635315813739055%
# (Epoch 15 / 50) Training Accuracy: 0.3863531581373905
# best performance 41.21715076071922%
# (Epoch 16 / 50) Training Accuracy: 0.41217150760719223
# (Iteration 3501 / 10800) loss: 135.01130018941032
# best performance 43.89119409866298%
# (Epoch 17 / 50) Training Accuracy: 0.4389119409866298
# best performance 45.965882895343476%
# (Epoch 18 / 50) Training Accuracy: 0.45965882895343474
# (Iteration 4001 / 10800) loss: 118.88978468959094
# best performance 48.45550945136007%
# (Epoch 19 / 50) Training Accuracy: 0.48455509451360074
# best performance 50.76071922544951%
# (Epoch 20 / 50) Training Accuracy: 0.5076071922544951
# (Iteration 4501 / 10800) loss: 107.81208766328086
# best performance 52.69709543568465%
# (Epoch 21 / 50) Training Accuracy: 0.5269709543568465
# best performance 54.034117104656524%
# (Epoch 22 / 50) Training Accuracy: 0.5403411710465652
# best performance 55.46334716459198%
# (Epoch 23 / 50) Training Accuracy: 0.5546334716459198
# (Iteration 5001 / 10800) loss: 101.9015757611901
# best performance 57.07699400645458%
# (Epoch 24 / 50) Training Accuracy: 0.5707699400645458
# best performance 58.46011987090826%
# (Epoch 25 / 50) Training Accuracy: 0.5846011987090826
# (Iteration 5501 / 10800) loss: 92.2295842749491
# best performance 59.5205163669894%
# (Epoch 26 / 50) Training Accuracy: 0.595205163669894
# best performance 61.50299677270632%
# (Epoch 27 / 50) Training Accuracy: 0.6150299677270632
# (Iteration 6001 / 10800) loss: 86.81137191045778
# best performance 62.286768095896726%
# (Epoch 28 / 50) Training Accuracy: 0.6228676809589673
# best performance 63.347164591977865%
# (Epoch 29 / 50) Training Accuracy: 0.6334716459197787
# best performance 64.63808206546796%
# (Epoch 30 / 50) Training Accuracy: 0.6463808206546796
# (Iteration 6501 / 10800) loss: 78.51495695791758
# best performance 65.42185338865836%
# (Epoch 31 / 50) Training Accuracy: 0.6542185338865837
# best performance 66.8971876440756%
# (Epoch 32 / 50) Training Accuracy: 0.6689718764407561
# (Iteration 7001 / 10800) loss: 75.32335960137479
# best performance 67.7731673582296%
# (Epoch 33 / 50) Training Accuracy: 0.677731673582296
# best performance 68.92577224527432%
# (Epoch 34 / 50) Training Accuracy: 0.6892577224527432
# (Iteration 7501 / 10800) loss: 67.21110675592465
# best performance 69.8017519594283%
# (Epoch 35 / 50) Training Accuracy: 0.698017519594283
# best performance 70.6777316735823%
# (Epoch 36 / 50) Training Accuracy: 0.706777316735823
# best performance 71.64591977869986%
# (Epoch 37 / 50) Training Accuracy: 0.7164591977869986
# (Iteration 8001 / 10800) loss: 65.63566307393086
# best performance 72.38358690640848%
# (Epoch 38 / 50) Training Accuracy: 0.7238358690640848
# best performance 72.98294144767173%
# (Epoch 39 / 50) Training Accuracy: 0.7298294144767173
# (Iteration 8501 / 10800) loss: 66.12617766118039
# best performance 73.30567081604426%
# (Epoch 40 / 50) Training Accuracy: 0.7330567081604425
# best performance 74.36606731212541%
# (Epoch 41 / 50) Training Accuracy: 0.7436606731212541
# (Iteration 9001 / 10800) loss: 53.86360052481264
# best performance 75.01152604887045%
# (Epoch 42 / 50) Training Accuracy: 0.7501152604887045
# best performance 75.51867219917013%
# (Epoch 43 / 50) Training Accuracy: 0.7551867219917012
# (Iteration 9501 / 10800) loss: 58.1690655658531
# best performance 75.70308898109728%
# (Epoch 44 / 50) Training Accuracy: 0.7570308898109728
# best performance 76.16413093591517%
# (Epoch 45 / 50) Training Accuracy: 0.7616413093591516
# best performance 76.71738128169665%
# (Epoch 46 / 50) Training Accuracy: 0.7671738128169664
# (Iteration 10001 / 10800) loss: 54.69251009746779
# best performance 77.13231904103274%
# (Epoch 47 / 50) Training Accuracy: 0.7713231904103274
# best performance 78.37713231904104%
# (Epoch 48 / 50) Training Accuracy: 0.7837713231904103
# (Iteration 10501 / 10800) loss: 52.44523089783049
# (Epoch 49 / 50) Training Accuracy: 0.7819271553711388
# best performance 78.60765329644998%
# (Epoch 50 / 50) Training Accuracy: 0.7860765329644998

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 15

idx = 0
# you also can start from specific word. 
# since the words are all converted into lower case
idx = int(np.where(np.asarray(word_list) == 'She'.lower())[0])

# sample from the trained model
words = model.sample(idx, text_length-1)

# convert indices into words
output = [ word_list[i] for i in words]
print(' '.join(output))
# Out:
# she tried to be seen: she found she was not a moment to get out

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 50

idx = 0
# you also can start from specific word. 
# since the words are all converted into lower case
idx = int(np.where(np.asarray(word_list) == 'She'.lower())[0])

# sample from the trained model
words = model.sample(idx, text_length-1)

# convert indices into words
output = [ word_list[i] for i in words]
print(' '.join(output))
# Out:
# she tried to be seen: she found she was not a moment to get out again.  there was nothing else to do, so alice had been this minute!’ she found so alice had been all the way down and cried.  ‘come, there’s no use in crying like that!’

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 20

start_words = ['alice!', 'alice', 'alice,', 'brave', 'this', 'that', 'that,']

for start_word in start_words:
    idx = 0
    # you also can start from specific word. 
    # since the words are all converted into lower case
    idx = int(np.where(np.asarray(word_list) == start_word.lower())[0])

    # sample from the trained model
    words = model.sample(idx, text_length-1)

    # convert indices into words
    output = [ word_list[i] for i in words]
    print(' '.join(output))
# Out:
# alice! said to herself, ‘which way? which way?’, holding her hand in the schoolroom, and found she found she was
# alice ventured to get out again.  there was nothing else to do, so alice had been this minute!’ she
# alice, ‘and even if you hold it too long; and her own ears for having cheated herself in a moment:
# brave they’ll remember the simple rules their friends had taught them: such as, that a red-hot poker will burn you
# this new zealand or australia?’ (and she tried to be seen: she found she was not a moment to get
# that she could not remember ever having seen such a thing.  she tried to be seen: she found she
# that, if i shall why, i wouldn’t say anything about stopping herself before she found she was not a moment

# %%
# %reload_ext autoreload

# you can change the following parameters.
D = 10 # input dimention
H = 40 # hidden space dimention
T = 50 # timesteps
N = 10 # batch size
max_epoch = 50 # max epoch size

loss_func = temporal_softmax_loss()
# you can change the cell_type between 'rnn' and 'lstm'.
model = LanguageModelRNN(dataSize, D, H, cell_type='rnn')
optimizer = Adam(model, 5e-4)

data = { 'data_train': data_labels, 'labels_train': gt_labels }

results = train_net(data, model, loss_func, optimizer, timesteps=T, batch_size=N, max_epochs=max_epoch, verbose=True)
#  Acc ~60%

opt_params, loss_hist, train_acc_hist = results

# Plot the learning curves
plt.subplot(2, 1, 1)
plt.title('Training loss')
loss_hist_ = loss_hist[1::100] # sparse the curve a bit
plt.plot(loss_hist_, '-o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(train_acc_hist, '-o', label='Training')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)

plt.show()
# 99.262%
# Out:
# (Iteration 1 / 10800) loss: 332.8400209778688
# best performance 3.503918856615952%
# (Epoch 1 / 50) Training Accuracy: 0.03503918856615952
# best performance 5.94744121715076%
# (Epoch 2 / 50) Training Accuracy: 0.059474412171507604
# (Iteration 501 / 10800) loss: 266.33167964894307
# best performance 7.791609036422314%
# (Epoch 3 / 50) Training Accuracy: 0.07791609036422315
# best performance 11.9870908252651%
# (Epoch 4 / 50) Training Accuracy: 0.119870908252651
# (Iteration 1001 / 10800) loss: 205.63916712593283
# best performance 17.196864914707238%
# (Epoch 5 / 50) Training Accuracy: 0.17196864914707238
# best performance 24.112494236975564%
# (Epoch 6 / 50) Training Accuracy: 0.24112494236975565
# (Iteration 1501 / 10800) loss: 161.25595446822226
# best performance 31.857999077916087%
# (Epoch 7 / 50) Training Accuracy: 0.3185799907791609
# best performance 39.60350391885662%
# (Epoch 8 / 50) Training Accuracy: 0.39603503918856614
# best performance 46.288612263716%
# (Epoch 9 / 50) Training Accuracy: 0.46288612263716
# (Iteration 2001 / 10800) loss: 117.41484284538328
# best performance 52.69709543568465%
# (Epoch 10 / 50) Training Accuracy: 0.5269709543568465
# best performance 58.36791147994468%
# (Epoch 11 / 50) Training Accuracy: 0.5836791147994468
# (Iteration 2501 / 10800) loss: 92.00136263011262
# best performance 63.48547717842323%
# (Epoch 12 / 50) Training Accuracy: 0.6348547717842323
# best performance 68.46473029045643%
# (Epoch 13 / 50) Training Accuracy: 0.6846473029045643
# (Iteration 3001 / 10800) loss: 76.18406824106391
# best performance 71.8764407561088%
# (Epoch 14 / 50) Training Accuracy: 0.7187644075610881
# best performance 74.8271092669433%
# (Epoch 15 / 50) Training Accuracy: 0.7482710926694329
# best performance 77.59336099585063%
# (Epoch 16 / 50) Training Accuracy: 0.7759336099585062
# (Iteration 3501 / 10800) loss: 59.242762322305225
# best performance 80.72844628861226%
# (Epoch 17 / 50) Training Accuracy: 0.8072844628861227
# best performance 83.54080221300138%
# (Epoch 18 / 50) Training Accuracy: 0.8354080221300139
# (Iteration 4001 / 10800) loss: 44.73729888347045
# best performance 86.30705394190872%
# (Epoch 19 / 50) Training Accuracy: 0.8630705394190872
# best performance 87.96680497925311%
# (Epoch 20 / 50) Training Accuracy: 0.8796680497925311
# (Iteration 4501 / 10800) loss: 36.95507822059268
# best performance 89.58045182111573%
# (Epoch 21 / 50) Training Accuracy: 0.8958045182111573
# best performance 90.54863992623329%
# (Epoch 22 / 50) Training Accuracy: 0.9054863992623329
# best performance 91.42461964038728%
# (Epoch 23 / 50) Training Accuracy: 0.9142461964038727
# (Iteration 5001 / 10800) loss: 28.73293916955752
# best performance 92.89995389580452%
# (Epoch 24 / 50) Training Accuracy: 0.9289995389580452
# best performance 93.82203780544029%
# (Epoch 25 / 50) Training Accuracy: 0.938220378054403
# (Iteration 5501 / 10800) loss: 26.119256446470803
# best performance 94.65191332411248%
# (Epoch 26 / 50) Training Accuracy: 0.9465191332411249
# best performance 95.15905947441216%
# (Epoch 27 / 50) Training Accuracy: 0.9515905947441217
# (Iteration 6001 / 10800) loss: 23.36019275857105
# best performance 95.66620562471185%
# (Epoch 28 / 50) Training Accuracy: 0.9566620562471185
# best performance 96.49608114338405%
# (Epoch 29 / 50) Training Accuracy: 0.9649608114338405
# best performance 97.04933148916551%
# (Epoch 30 / 50) Training Accuracy: 0.9704933148916551
# (Iteration 6501 / 10800) loss: 20.996709508165775
# best performance 97.5103734439834%
# (Epoch 31 / 50) Training Accuracy: 0.975103734439834
# best performance 97.64868603042876%
# (Epoch 32 / 50) Training Accuracy: 0.9764868603042877
# (Iteration 7001 / 10800) loss: 21.95585714928099
# best performance 98.06362378976486%
# (Epoch 33 / 50) Training Accuracy: 0.9806362378976486
# best performance 98.3402489626556%
# (Epoch 34 / 50) Training Accuracy: 0.983402489626556
# (Iteration 7501 / 10800) loss: 16.952273815968233
# best performance 98.43245735361917%
# (Epoch 35 / 50) Training Accuracy: 0.9843245735361917
# best performance 98.66297833102813%
# (Epoch 36 / 50) Training Accuracy: 0.9866297833102813
# (Epoch 37 / 50) Training Accuracy: 0.9866297833102813
# (Iteration 8001 / 10800) loss: 15.43643733511629
# best performance 98.93960350391886%
# (Epoch 38 / 50) Training Accuracy: 0.9893960350391886
# best performance 99.07791609036423%
# (Epoch 39 / 50) Training Accuracy: 0.9907791609036423
# (Iteration 8501 / 10800) loss: 11.070654864530074
# (Epoch 40 / 50) Training Accuracy: 0.9907791609036423
# best performance 99.12402028584602%
# (Epoch 41 / 50) Training Accuracy: 0.9912402028584602
# (Iteration 9001 / 10800) loss: 13.055192592156425
# (Epoch 42 / 50) Training Accuracy: 0.9903181189488244
# (Epoch 43 / 50) Training Accuracy: 0.9907791609036423
# (Iteration 9501 / 10800) loss: 13.16832161739585
# best performance 99.1701244813278%
# (Epoch 44 / 50) Training Accuracy: 0.991701244813278
# best performance 99.21622867680959%
# (Epoch 45 / 50) Training Accuracy: 0.9921622867680959
# best performance 99.26233287229138%
# (Epoch 46 / 50) Training Accuracy: 0.9926233287229138
# (Iteration 10001 / 10800) loss: 13.161344941314226
# best performance 99.30843706777317%
# (Epoch 47 / 50) Training Accuracy: 0.9930843706777317
# (Epoch 48 / 50) Training Accuracy: 0.9930843706777317
# (Iteration 10501 / 10800) loss: 15.088588543003379
# (Epoch 49 / 50) Training Accuracy: 0.9926233287229138
# (Epoch 50 / 50) Training Accuracy: 0.9926233287229138

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 50

idx = 0
# you also can start from specific word. 
# since the words are all converted into lower case
idx = int(np.where(np.asarray(word_list) == 'She'.lower())[0])

# sample from the trained model
words = model.sample(idx, text_length-1)

# convert indices into words
output = [ word_list[i] for i in words]
print(' '.join(output))
# Out:
# she tried to fancy what the flame of a candle is like after the candle is blown out, for she could not remember ever having seen such a thing.  after a while, finding that nothing more happened, she decided on going into the garden at once; but, alas for

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 20

start_words = ['alice!', 'alice', 'alice,', 'brave', 'this', 'that', 'that,']

for start_word in start_words:
    idx = 0
    # you also can start from specific word. 
    # since the words are all converted into lower case
    idx = int(np.where(np.asarray(word_list) == start_word.lower())[0])

    # sample from the trained model
    words = model.sample(idx, text_length-1)

    # convert indices into words
    output = [ word_list[i] for i in words]
    print(' '.join(output))
# Out:
# alice! for asking! no, it’ll never do to ask: perhaps i shall see it written up somewhere.’  down, down,
# alice had been all the way down one side and up the other, trying every door, she walked sadly down
# alice, ‘and not a moment to be lost: away went alice like the wind, and was just in time to
# brave but the rabbit was no longer to be seen: she found herself in a long, low hall, which was
# this minute!’ she generally gave herself very good advice, (though she very seldom followed it), and sometimes she scolded herself
# that she was now only ten inches high, and her face brightened up at the thought that she was now
# that, all made of solid glass; there was nothing on it except a tiny golden key, and alice’s first thought

# %%
# %reload_ext autoreload

# you can change the following parameters.
D = 10 # input dimention
H = 40 # hidden space dimention
T = 50 # timesteps
N = 10 # batch size
max_epoch = 50 # max epoch size

loss_func = temporal_softmax_loss()
# you can change the cell_type between 'rnn' and 'lstm'.
model = LanguageModelRNN(dataSize, D, H, cell_type='lstm')
optimizer = Adam(model, 5e-4)

data = { 'data_train': data_labels, 'labels_train': gt_labels }

results = train_net(data, model, loss_func, optimizer, timesteps=T, batch_size=N, max_epochs=max_epoch, verbose=True)
#  Acc ~60%

opt_params, loss_hist, train_acc_hist = results

# Plot the learning curves
plt.subplot(2, 1, 1)
plt.title('Training loss')
loss_hist_ = loss_hist[1::100] # sparse the curve a bit
plt.plot(loss_hist_, '-o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(train_acc_hist, '-o', label='Training')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)

plt.show()
# 99.12
# Out:
# (Iteration 1 / 10800) loss: 332.8415910412499
# best performance 3.5961272475795294%
# (Epoch 1 / 50) Training Accuracy: 0.035961272475795295
# best performance 4.149377593360995%
# (Epoch 2 / 50) Training Accuracy: 0.04149377593360996
# (Iteration 501 / 10800) loss: 294.06151331443687
# (Epoch 3 / 50) Training Accuracy: 0.04103273397879207
# best performance 6.500691562932228%
# (Epoch 4 / 50) Training Accuracy: 0.06500691562932227
# (Iteration 1001 / 10800) loss: 245.33494574557443
# best performance 8.252650991240202%
# (Epoch 5 / 50) Training Accuracy: 0.08252650991240203
# best performance 11.065006915629322%
# (Epoch 6 / 50) Training Accuracy: 0.11065006915629322
# (Iteration 1501 / 10800) loss: 201.2115803855777
# best performance 14.615029967727065%
# (Epoch 7 / 50) Training Accuracy: 0.14615029967727064
# best performance 18.533886583679116%
# (Epoch 8 / 50) Training Accuracy: 0.18533886583679116
# best performance 22.083909635776855%
# (Epoch 9 / 50) Training Accuracy: 0.22083909635776855
# (Iteration 2001 / 10800) loss: 174.62088122353413
# best performance 28.769017980636235%
# (Epoch 10 / 50) Training Accuracy: 0.28769017980636236
# best performance 34.53204241585984%
# (Epoch 11 / 50) Training Accuracy: 0.3453204241585984
# (Iteration 2501 / 10800) loss: 137.6387128565662
# best performance 40.57169202397418%
# (Epoch 12 / 50) Training Accuracy: 0.4057169202397418
# best performance 47.16459197786998%
# (Epoch 13 / 50) Training Accuracy: 0.47164591977869985
# (Iteration 3001 / 10800) loss: 118.6015662772674
# best performance 51.82111572153067%
# (Epoch 14 / 50) Training Accuracy: 0.5182111572153066
# best performance 57.21530659289995%
# (Epoch 15 / 50) Training Accuracy: 0.5721530659289995
# best performance 62.05624711848778%
# (Epoch 16 / 50) Training Accuracy: 0.6205624711848778
# (Iteration 3501 / 10800) loss: 97.93037498150643
# best performance 66.29783310281235%
# (Epoch 17 / 50) Training Accuracy: 0.6629783310281235
# best performance 70.17058552328261%
# (Epoch 18 / 50) Training Accuracy: 0.7017058552328261
# (Iteration 4001 / 10800) loss: 84.2795339699948
# best performance 72.98294144767173%
# (Epoch 19 / 50) Training Accuracy: 0.7298294144767173
# best performance 75.70308898109728%
# (Epoch 20 / 50) Training Accuracy: 0.7570308898109728
# (Iteration 4501 / 10800) loss: 71.84719282835582
# best performance 78.1005071461503%
# (Epoch 21 / 50) Training Accuracy: 0.781005071461503
# best performance 80.22130013831259%
# (Epoch 22 / 50) Training Accuracy: 0.8022130013831259
# best performance 82.34209313047486%
# (Epoch 23 / 50) Training Accuracy: 0.8234209313047487
# (Iteration 5001 / 10800) loss: 68.13593067310232
# best performance 83.54080221300138%
# (Epoch 24 / 50) Training Accuracy: 0.8354080221300139
# best performance 85.06224066390041%
# (Epoch 25 / 50) Training Accuracy: 0.8506224066390041
# (Iteration 5501 / 10800) loss: 51.40078215528403
# best performance 86.44536652835409%
# (Epoch 26 / 50) Training Accuracy: 0.8644536652835408
# best performance 88.33563854310742%
# (Epoch 27 / 50) Training Accuracy: 0.8833563854310742
# (Iteration 6001 / 10800) loss: 45.03739532173232
# best performance 89.303826648225%
# (Epoch 28 / 50) Training Accuracy: 0.8930382664822499
# best performance 90.31811894882435%
# (Epoch 29 / 50) Training Accuracy: 0.9031811894882434
# best performance 91.28630705394191%
# (Epoch 30 / 50) Training Accuracy: 0.9128630705394191
# (Iteration 6501 / 10800) loss: 35.54590222780706
# best performance 92.48501613646842%
# (Epoch 31 / 50) Training Accuracy: 0.9248501613646842
# best performance 93.31489165514061%
# (Epoch 32 / 50) Training Accuracy: 0.9331489165514062
# (Iteration 7001 / 10800) loss: 34.60200443888699
# best performance 94.05255878284923%
# (Epoch 33 / 50) Training Accuracy: 0.9405255878284924
# best performance 94.974642692485%
# (Epoch 34 / 50) Training Accuracy: 0.9497464269248501
# (Iteration 7501 / 10800) loss: 30.68291891223701
# best performance 95.4817888427847%
# (Epoch 35 / 50) Training Accuracy: 0.954817888427847
# best performance 96.03503918856616%
# (Epoch 36 / 50) Training Accuracy: 0.9603503918856616
# best performance 96.63439372982941%
# (Epoch 37 / 50) Training Accuracy: 0.9663439372982942
# (Iteration 8001 / 10800) loss: 28.072999887521092
# best performance 97.37206085753803%
# (Epoch 38 / 50) Training Accuracy: 0.9737206085753803
# best performance 97.60258183494697%
# (Epoch 39 / 50) Training Accuracy: 0.9760258183494698
# (Iteration 8501 / 10800) loss: 24.10895543595961
# best performance 98.01751959428307%
# (Epoch 40 / 50) Training Accuracy: 0.9801751959428308
# best performance 98.06362378976486%
# (Epoch 41 / 50) Training Accuracy: 0.9806362378976486
# (Iteration 9001 / 10800) loss: 22.866316125908376
# best performance 98.24804057169202%
# (Epoch 42 / 50) Training Accuracy: 0.9824804057169202
# best performance 98.38635315813738%
# (Epoch 43 / 50) Training Accuracy: 0.9838635315813739
# (Iteration 9501 / 10800) loss: 18.472561016489692
# best performance 98.57076994006455%
# (Epoch 44 / 50) Training Accuracy: 0.9857076994006455
# best performance 98.70908252650992%
# (Epoch 45 / 50) Training Accuracy: 0.9870908252650992
# (Epoch 46 / 50) Training Accuracy: 0.9866297833102813
# (Iteration 10001 / 10800) loss: 18.754977133164097
# best performance 98.8012909174735%
# (Epoch 47 / 50) Training Accuracy: 0.9880129091747349
# best performance 98.84739511295528%
# (Epoch 48 / 50) Training Accuracy: 0.9884739511295528
# (Iteration 10501 / 10800) loss: 18.25985875553784
# (Epoch 49 / 50) Training Accuracy: 0.9884739511295528
# best performance 99.12402028584602%
# (Epoch 50 / 50) Training Accuracy: 0.9912402028584602

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 100

start_words = ['She', 'alice!', 'alice', 'alice,', 'brave', 'this', 'that', 'that,']

for start_word in start_words:
    idx = 0
    # you also can start from specific word. 
    # since the words are all converted into lower case
    idx = int(np.where(np.asarray(word_list) == start_word.lower())[0])

    # sample from the trained model
    words = model.sample(idx, text_length-1)

    # convert indices into words
    output = [ word_list[i] for i in words]
    print(' '.join(output))
    print('\n')
# Out:
# she was not a moment to be lost: away went alice like the wind, and was just in time to hear it say, as it turned a corner, ‘oh my ears and whiskers, how late it’s getting!’ she was close behind it when she turned the corner, but it was all very well to say ‘drink me,’ but the wise little alice was not going to do that she was walking hand in hand with dinah, and saying to her very earnestly, ‘now, dinah, tell me the truth: did you ever eat a bat?’ when suddenly, thump! thump! down she
#
#
# alice! when she had tired herself out with trying, the poor little thing sat down and cried.  ‘come, there’s no use in crying like that!’ said alice to herself, ‘in my going out altogether, like a candle. i wonder what i should be like then?’ and she tried to fancy what the flame of a candle is like after the candle is blown out, for she could not remember ever having seen such a thing.  after a while, finding that nothing more happened, she decided on going into the garden at once; but, alas for poor alice! when
#
#
# alice to see anything; then she looked at the sides of the well, and noticed that they were filled with cupboards and book-shelves; here and there she saw maps and pictures hung upon pegs. she took down a jar from one of the shelves as she passed; it was labelled ‘orange marmalade’, but to her great disappointment it was empty: she did not like to drop the jar for fear of killing somebody, so managed to put it into one of the cupboards as she fell past it.  ‘well!’ thought alice to herself, ‘after such a fall as this,
#
#
# alice, ‘and if it makes me grow smaller, i can creep under the door; so either way i’ll get into the garden, and i don’t care which happens!’  she ate a little bit, and said anxiously to herself, ‘which way? which way?’, holding her hand on the top of her head to feel which way it was growing, and she was quite surprised to find that she remained the same size: to be sure, this generally happens when one eats cake, but alice had got so much into the way of expecting nothing but out-of-the-way things to happen, that
#
#
# brave first thought she was now the right size for going through the little door into that lovely garden. first, however, she waited for a few minutes to see if she was going to shrink any further: she felt a little nervous about this; ‘for it might end, you know,’ said alice to herself, ‘in my going out altogether, like a candle. i wonder what i should be like then?’ and she tried to fancy what the flame of a candle is like after the candle is blown out, for she could not remember ever having seen such a thing.
#
#
# this sort of the earth. let me see: that would be four thousand miles down, i think--’ (for, you see, alice had learnt several things of this sort in her lessons in the schoolroom, and though this was not a moment to be two people. ‘but it’s no use now,’ thought poor alice, ‘to pretend to be two people! why, there’s hardly enough of me left to make one respectable person!’  soon her eye fell on a little glass box that was lying under the table: she opened it, and found in it a very small cake, on which
#
#
# that she found herself falling down a very deep well.  either the well was very deep, or she fell very slowly, for she had plenty of time as she went down to look about her herself in the words ‘eat me’ were beautifully marked in currants. ‘well, i’ll eat it,’ said alice, ‘and if it makes me grow larger, i can reach the key; and if it makes me grow smaller, i can creep under the door; so either way i’ll get into the garden, and i don’t care which happens!’  she ate a little bit, and said
#
#
# that, was not a moment to be lost: away went alice like the wind, and was just in time to hear it say, as it turned a corner, ‘oh my ears and whiskers, how late it’s getting!’ she was close behind it when she turned the corner, but it was all very well to say ‘drink me,’ but the wise little alice was not going to do that she was walking hand in hand with dinah, and saying to her very earnestly, ‘now, dinah, tell me the truth: did you ever eat a bat?’ when suddenly, thump! thump! down she

# %%
# %reload_ext autoreload

# you can change the following parameters.
D = 10 # input dimention
H = 50 # hidden space dimention
T = 50 # timesteps
N = 10 # batch size
max_epoch = 50 # max epoch size

loss_func = temporal_softmax_loss()
# you can change the cell_type between 'rnn' and 'lstm'.
model = LanguageModelRNN(dataSize, D, H, cell_type='lstm')
optimizer = Adam(model, 5e-4)

data = { 'data_train': data_labels, 'labels_train': gt_labels }

results = train_net(data, model, loss_func, optimizer, timesteps=T, batch_size=N, max_epochs=max_epoch, verbose=True)
#  Acc ~60%

opt_params, loss_hist, train_acc_hist = results

# Plot the learning curves
plt.subplot(2, 1, 1)
plt.title('Training loss')
loss_hist_ = loss_hist[1::100] # sparse the curve a bit
plt.plot(loss_hist_, '-o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(train_acc_hist, '-o', label='Training')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)

plt.show()
# 99.44
# Out:
# (Iteration 1 / 10800) loss: 332.82961300643893
# best performance 3.5961272475795294%
# (Epoch 1 / 50) Training Accuracy: 0.035961272475795295
# best performance 4.5182111572153065%
# (Epoch 2 / 50) Training Accuracy: 0.045182111572153065
# (Iteration 501 / 10800) loss: 274.70393068379434
# best performance 5.394190871369295%
# (Epoch 3 / 50) Training Accuracy: 0.05394190871369295
# best performance 9.082526509912402%
# (Epoch 4 / 50) Training Accuracy: 0.09082526509912402
# (Iteration 1001 / 10800) loss: 219.39993129188497
# best performance 12.955278930382667%
# (Epoch 5 / 50) Training Accuracy: 0.12955278930382666
# best performance 20.2397418165053%
# (Epoch 6 / 50) Training Accuracy: 0.20239741816505302
# (Iteration 1501 / 10800) loss: 171.02373105393744
# best performance 27.708621484555096%
# (Epoch 7 / 50) Training Accuracy: 0.27708621484555096
# best performance 36.83725218994929%
# (Epoch 8 / 50) Training Accuracy: 0.3683725218994929
# best performance 46.93407100046104%
# (Epoch 9 / 50) Training Accuracy: 0.4693407100046104
# (Iteration 2001 / 10800) loss: 135.47494618898492
# best performance 54.310742277547256%
# (Epoch 10 / 50) Training Accuracy: 0.5431074227754725
# best performance 60.81143384047948%
# (Epoch 11 / 50) Training Accuracy: 0.6081143384047948
# (Iteration 2501 / 10800) loss: 101.29309659505842
# best performance 66.52835408022129%
# (Epoch 12 / 50) Training Accuracy: 0.665283540802213
# best performance 71.46150299677271%
# (Epoch 13 / 50) Training Accuracy: 0.7146150299677271
# (Iteration 3001 / 10800) loss: 79.62105179144139
# best performance 74.91931765790687%
# (Epoch 14 / 50) Training Accuracy: 0.7491931765790687
# best performance 78.23881973259567%
# (Epoch 15 / 50) Training Accuracy: 0.7823881973259567
# best performance 81.28169663439373%
# (Epoch 16 / 50) Training Accuracy: 0.8128169663439373
# (Iteration 3501 / 10800) loss: 71.74035090513236
# best performance 83.4946980175196%
# (Epoch 17 / 50) Training Accuracy: 0.834946980175196
# best performance 86.44536652835409%
# (Epoch 18 / 50) Training Accuracy: 0.8644536652835408
# (Iteration 4001 / 10800) loss: 55.57074525925225
# best performance 88.56615952051636%
# (Epoch 19 / 50) Training Accuracy: 0.8856615952051636
# best performance 89.76486860304288%
# (Epoch 20 / 50) Training Accuracy: 0.8976486860304288
# (Iteration 4501 / 10800) loss: 43.201885104108676
# best performance 91.42461964038728%
# (Epoch 21 / 50) Training Accuracy: 0.9142461964038727
# best performance 92.85384970032273%
# (Epoch 22 / 50) Training Accuracy: 0.9285384970032273
# best performance 93.96035039188565%
# (Epoch 23 / 50) Training Accuracy: 0.9396035039188566
# (Iteration 5001 / 10800) loss: 36.4383231934053
# best performance 94.83633010603964%
# (Epoch 24 / 50) Training Accuracy: 0.9483633010603965
# best performance 95.850622406639%
# (Epoch 25 / 50) Training Accuracy: 0.9585062240663901
# (Iteration 5501 / 10800) loss: 33.403615582748664
# best performance 96.49608114338405%
# (Epoch 26 / 50) Training Accuracy: 0.9649608114338405
# best performance 96.95712309820193%
# (Epoch 27 / 50) Training Accuracy: 0.9695712309820194
# (Iteration 6001 / 10800) loss: 28.314013222355452
# best performance 97.32595666205624%
# (Epoch 28 / 50) Training Accuracy: 0.9732595666205625
# best performance 97.69479022591055%
# (Epoch 29 / 50) Training Accuracy: 0.9769479022591055
# best performance 98.10972798524665%
# (Epoch 30 / 50) Training Accuracy: 0.9810972798524665
# (Iteration 6501 / 10800) loss: 23.42073822273789
# best performance 98.61687413554634%
# (Epoch 31 / 50) Training Accuracy: 0.9861687413554634
# (Epoch 32 / 50) Training Accuracy: 0.9861687413554634
# (Iteration 7001 / 10800) loss: 19.527989149771987
# best performance 98.93960350391886%
# (Epoch 33 / 50) Training Accuracy: 0.9893960350391886
# (Epoch 34 / 50) Training Accuracy: 0.9889349930843707
# (Iteration 7501 / 10800) loss: 15.651704621588044
# best performance 98.98570769940065%
# (Epoch 35 / 50) Training Accuracy: 0.9898570769940065
# best performance 99.03181189488244%
# (Epoch 36 / 50) Training Accuracy: 0.9903181189488244
# best performance 99.1701244813278%
# (Epoch 37 / 50) Training Accuracy: 0.991701244813278
# (Iteration 8001 / 10800) loss: 15.841278657562341
# (Epoch 38 / 50) Training Accuracy: 0.991701244813278
# best performance 99.26233287229138%
# (Epoch 39 / 50) Training Accuracy: 0.9926233287229138
# (Iteration 8501 / 10800) loss: 14.622358328959013
# (Epoch 40 / 50) Training Accuracy: 0.9926233287229138
# (Epoch 41 / 50) Training Accuracy: 0.9926233287229138
# (Iteration 9001 / 10800) loss: 12.574311883317325
# best performance 99.35454126325496%
# (Epoch 42 / 50) Training Accuracy: 0.9935454126325496
# best performance 99.40064545873675%
# (Epoch 43 / 50) Training Accuracy: 0.9940064545873675
# (Iteration 9501 / 10800) loss: 13.917788149869898
# (Epoch 44 / 50) Training Accuracy: 0.9940064545873675
# (Epoch 45 / 50) Training Accuracy: 0.9940064545873675
# (Epoch 46 / 50) Training Accuracy: 0.9935454126325496
# (Iteration 10001 / 10800) loss: 10.855207004812092
# (Epoch 47 / 50) Training Accuracy: 0.9940064545873675
# (Epoch 48 / 50) Training Accuracy: 0.9940064545873675
# (Iteration 10501 / 10800) loss: 12.286610611930781
# (Epoch 49 / 50) Training Accuracy: 0.9940064545873675
# best performance 99.44674965421854%
# (Epoch 50 / 50) Training Accuracy: 0.9944674965421854

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 50

idx = 0
# you also can start from specific word. 
# since the words are all converted into lower case
idx = int(np.where(np.asarray(word_list) == 'She'.lower())[0])

# sample from the trained model
words = model.sample(idx, text_length-1)

# convert indices into words
output = [ word_list[i] for i in words]
print(' '.join(output))
# Out:
# she was quite surprised to find that she remained the same size: to be sure, this generally happens when one eats cake, but alice had got so much into the way of expecting nothing but out-of-the-way things to happen, that it seemed quite dull and stupid for life to go

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 100

idx = 0
# you also can start from specific word. 
# since the words are all converted into lower case
idx = int(np.where(np.asarray(word_list) == 'She'.lower())[0])

# sample from the trained model
words = model.sample(idx, text_length-1)

# convert indices into words
output = [ word_list[i] for i in words]
print(' '.join(output))
# Out:
# she was quite surprised to find that she remained the same size: to be sure, this generally happens when one eats cake, but alice had got so much into the way of expecting nothing but out-of-the-way things to happen, that it seemed quite dull and stupid for life to go on in the common way.  so she set to work, and the fall was over.  alice was not a bit hurt, and she jumped up on to her feet in a moment: she looked up, but it was all dark overhead; before her was another long passage, and

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 100

start_words = ['alice!', 'alice', 'alice,', 'brave', 'this', 'that', 'that,']

for start_word in start_words:
    idx = 0
    # you also can start from specific word. 
    # since the words are all converted into lower case
    idx = int(np.where(np.asarray(word_list) == start_word.lower())[0])

    # sample from the trained model
    words = model.sample(idx, text_length-1)

    # convert indices into words
    output = [ word_list[i] for i in words]
    print(' '.join(output))
    print('\n')
# Out:
# alice! when the schoolroom, and though this was not a very good opportunity for showing off her knowledge, as there was no one to listen to her, still it was good practice to say it over) ‘--yes, that’s about the right distance--but then i wonder what latitude or longitude i’ve got to?’ (alice had no idea what latitude was, or longitude either, but thought they were nice grand words to say.)  presently she began again. ‘i wonder if i shall fall right through the earth! how funny it’ll seem to come out among the people that walk with their
#
#
# alice after it, and fortunately was just in time to see it pop down a large rabbit-hole under the hedge.  in another moment down went alice after it, never once considering how in the world she was to get out again.  the rabbit-hole went straight on like a tunnel for some way, and then dipped suddenly down, so suddenly that alice had not a moment to think about stopping herself before she found herself falling down a very deep well.  either the well was very deep, or she fell very slowly, for she had plenty of time
#
#
# alice, ‘and she was close behind it when she turned the corner, but the rabbit was no longer to be seen: she found herself in a long, low hall, which was lit up by a row of lamps hanging from the roof.  there were doors all round the hall, but they were all locked; and when alice had been all the way down one side and up the other, trying every door, she walked sadly down the middle, wondering how she was ever to get out again.  suddenly she came upon a little three-legged table, all made of
#
#
# brave got to?’ (alice had no idea what latitude was, or longitude either, but thought they were nice grand words to say.)  presently she began again. ‘i wonder if i shall fall right through the earth! how funny it’ll seem to come out among the people that walk with their heads downward! the antipathies, i think--’ (she was rather glad there was no one listening, this time, as it didn’t sound at all the right word) ‘--but i shall have to ask them what the name of the country is, you know. please, ma’am, is this new zealand or
#
#
# this was not here before,’ said alice,) and round the neck of the bottle was a paper label, with the words ‘drink me’ beautifully printed on it in large letters.  it was all very well to say ‘drink me,’ but the wise little alice was not going to do that in a hurry. ‘no, i’ll look first,’ she said, ‘and see whether it’s marked “poison” or not’; for she had read several nice little histories about children who had got burnt, and eaten up by wild beasts and other unpleasant things, all because they would not remember the simple
#
#
# that it was growing, and so that it was all very well to say ‘drink me,’ but the wise little alice was not going to do that in a hurry. ‘no, i’ll look first,’ she said, ‘and see whether it’s marked “poison” or not’; for she had read several nice little histories about children who had got burnt, and eaten up by wild beasts and other unpleasant things, all because they would not remember the simple rules their friends had taught them: such as, that a red-hot poker will burn you if you hold it too long; and that if
#
#
# that, if you hold it too long; and that if you cut your finger very deeply with a knife, it usually bleeds; and she had never forgotten that, if you drink much from a bottle marked ‘poison,’ it is almost certain to disagree with you, sooner or later.  however, this bottle was not marked ‘poison,’ so alice ventured to taste it, and finding it very nice, (it had, in fact, a sort of mixed flavour of cherry-tart, custard, pine-apple, roast turkey, toffee, and hot buttered toast,) she very soon finished it off.  ‘what a curious feeling!’ said alice;

# %%
# %reload_ext autoreload

# you can change the following parameters.
D = 10 # input dimention
H = 50 # hidden space dimention
T = 10 # timesteps
N = 10 # batch size
max_epoch = 50 # max epoch size

loss_func = temporal_softmax_loss()
# you can change the cell_type between 'rnn' and 'lstm'.
model = LanguageModelRNN(dataSize, D, H, cell_type='rnn')
optimizer = Adam(model, 5e-4)

data = { 'data_train': data_labels, 'labels_train': gt_labels }

results = train_net(data, model, loss_func, optimizer, timesteps=T, batch_size=N, max_epochs=max_epoch, verbose=True)
#  Acc ~60%

opt_params, loss_hist, train_acc_hist = results

# Plot the learning curves
plt.subplot(2, 1, 1)
plt.title('Training loss')
loss_hist_ = loss_hist[1::100] # sparse the curve a bit
plt.plot(loss_hist_, '-o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(train_acc_hist, '-o', label='Training')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)

plt.show()
# 93.222
# Out:
# (Iteration 1 / 10800) loss: 66.56871246403338
# best performance 4.610419548178885%
# (Epoch 1 / 50) Training Accuracy: 0.046104195481788846
# best performance 5.94744121715076%
# (Epoch 2 / 50) Training Accuracy: 0.059474412171507604
# (Iteration 501 / 10800) loss: 57.756973489690964
# best performance 7.192254495159059%
# (Epoch 3 / 50) Training Accuracy: 0.07192254495159059
# best performance 9.58967266021208%
# (Epoch 4 / 50) Training Accuracy: 0.0958967266021208
# (Iteration 1001 / 10800) loss: 47.21171511972628
# best performance 12.079299216228677%
# (Epoch 5 / 50) Training Accuracy: 0.12079299216228677
# best performance 16.459197786998615%
# (Epoch 6 / 50) Training Accuracy: 0.16459197786998617
# (Iteration 1501 / 10800) loss: 38.53690194566303
# best performance 21.254034117104656%
# (Epoch 7 / 50) Training Accuracy: 0.21254034117104656
# best performance 25.633932687874594%
# (Epoch 8 / 50) Training Accuracy: 0.25633932687874594
# best performance 29.59889349930844%
# (Epoch 9 / 50) Training Accuracy: 0.2959889349930844
# (Iteration 2001 / 10800) loss: 34.28333784077343
# best performance 33.84047948363301%
# (Epoch 10 / 50) Training Accuracy: 0.3384047948363301
# best performance 38.40479483633011%
# (Epoch 11 / 50) Training Accuracy: 0.3840479483633011
# (Iteration 2501 / 10800) loss: 28.43680948009245
# best performance 42.50806823420931%
# (Epoch 12 / 50) Training Accuracy: 0.4250806823420931
# best performance 47.072383586906405%
# (Epoch 13 / 50) Training Accuracy: 0.4707238358690641
# (Iteration 3001 / 10800) loss: 26.43632771007679
# best performance 50.48409405255878%
# (Epoch 14 / 50) Training Accuracy: 0.5048409405255878
# best performance 52.927616413093595%
# (Epoch 15 / 50) Training Accuracy: 0.5292761641309359
# best performance 55.09451360073767%
# (Epoch 16 / 50) Training Accuracy: 0.5509451360073767
# (Iteration 3501 / 10800) loss: 24.787849223589497
# best performance 57.99907791609037%
# (Epoch 17 / 50) Training Accuracy: 0.5799907791609037
# best performance 59.84324573536192%
# (Epoch 18 / 50) Training Accuracy: 0.5984324573536192
# (Iteration 4001 / 10800) loss: 18.309909110038298
# best performance 62.47118487782388%
# (Epoch 19 / 50) Training Accuracy: 0.6247118487782388
# best performance 64.08483171968649%
# (Epoch 20 / 50) Training Accuracy: 0.640848317196865
# (Iteration 4501 / 10800) loss: 18.870823728800293
# best performance 65.60627017058552%
# (Epoch 21 / 50) Training Accuracy: 0.6560627017058552
# best performance 67.49654218533887%
# (Epoch 22 / 50) Training Accuracy: 0.6749654218533887
# best performance 69.61733517750115%
# (Epoch 23 / 50) Training Accuracy: 0.6961733517750115
# (Iteration 5001 / 10800) loss: 17.006505663605715
# best performance 71.5076071922545%
# (Epoch 24 / 50) Training Accuracy: 0.715076071922545
# best performance 73.582295988935%
# (Epoch 25 / 50) Training Accuracy: 0.73582295988935
# (Iteration 5501 / 10800) loss: 17.179912971725866
# best performance 75.1959428307976%
# (Epoch 26 / 50) Training Accuracy: 0.751959428307976
# best performance 76.30244352236053%
# (Epoch 27 / 50) Training Accuracy: 0.7630244352236053
# (Iteration 6001 / 10800) loss: 16.519782009436106
# best performance 77.59336099585063%
# (Epoch 28 / 50) Training Accuracy: 0.7759336099585062
# best performance 78.60765329644998%
# (Epoch 29 / 50) Training Accuracy: 0.7860765329644998
# best performance 79.80636237897649%
# (Epoch 30 / 50) Training Accuracy: 0.7980636237897649
# (Iteration 6501 / 10800) loss: 14.636764157881638
# best performance 80.45182111572153%
# (Epoch 31 / 50) Training Accuracy: 0.8045182111572153
# best performance 81.46611341632088%
# (Epoch 32 / 50) Training Accuracy: 0.8146611341632088
# (Iteration 7001 / 10800) loss: 12.65947791617037
# best performance 81.97325956662056%
# (Epoch 33 / 50) Training Accuracy: 0.8197325956662056
# best performance 83.81742738589212%
# (Epoch 34 / 50) Training Accuracy: 0.8381742738589212
# (Iteration 7501 / 10800) loss: 12.045749307715893
# best performance 84.37067773167358%
# (Epoch 35 / 50) Training Accuracy: 0.8437067773167358
# best performance 85.06224066390041%
# (Epoch 36 / 50) Training Accuracy: 0.8506224066390041
# best performance 86.03042876901799%
# (Epoch 37 / 50) Training Accuracy: 0.8603042876901799
# (Iteration 8001 / 10800) loss: 11.473616456822045
# best performance 86.90640848317197%
# (Epoch 38 / 50) Training Accuracy: 0.8690640848317197
# best performance 87.69017980636238%
# (Epoch 39 / 50) Training Accuracy: 0.8769017980636238
# (Iteration 8501 / 10800) loss: 12.582051446538241
# best performance 88.52005532503458%
# (Epoch 40 / 50) Training Accuracy: 0.8852005532503457
# best performance 89.11940986629784%
# (Epoch 41 / 50) Training Accuracy: 0.8911940986629784
# (Iteration 9001 / 10800) loss: 13.090605652184445
# best performance 89.62655601659752%
# (Epoch 42 / 50) Training Accuracy: 0.8962655601659751
# best performance 90.64084831719687%
# (Epoch 43 / 50) Training Accuracy: 0.9064084831719686
# (Iteration 9501 / 10800) loss: 10.167567987774188
# best performance 90.77916090364224%
# (Epoch 44 / 50) Training Accuracy: 0.9077916090364223
# best performance 91.19409866297833%
# (Epoch 45 / 50) Training Accuracy: 0.9119409866297833
# best performance 91.88566159520516%
# (Epoch 46 / 50) Training Accuracy: 0.9188566159520516
# (Iteration 10001 / 10800) loss: 9.50110188027831
# best performance 92.02397418165053%
# (Epoch 47 / 50) Training Accuracy: 0.9202397418165053
# best performance 92.99216228676809%
# (Epoch 48 / 50) Training Accuracy: 0.929921622867681
# (Iteration 10501 / 10800) loss: 9.359428039952858
# best performance 93.3609958506224%
# (Epoch 49 / 50) Training Accuracy: 0.9336099585062241
# (Epoch 50 / 50) Training Accuracy: 0.9322268326417704

# %%
# %reload_ext autoreload

# you can change the generated text length below.
text_length = 100

start_words = ['She', 'alice!', 'alice', 'alice,', 'brave', 'this', 'that', 'that,']

for start_word in start_words:
    idx = 0
    # you also can start from specific word. 
    # since the words are all converted into lower case
    idx = int(np.where(np.asarray(word_list) == start_word.lower())[0])

    # sample from the trained model
    words = model.sample(idx, text_length-1)

    # convert indices into words
    output = [ word_list[i] for i in words]
    print(' '.join(output))
    print('\n')
# Out:
# she had forgotten the little golden key, and when she had tired herself so severely as to bring tears into her eyes; and once she remembered trying to box her own ears for having cheated herself in a game of croquet she was playing against herself, for this curious child was very fond the rabbit that she was now only ten inches high, and her face brightened up at the thought it pop down a large rabbit-hole under the hedge.  in another moment down went alice after it, never once considering how in the world she was to get
#
#
# alice! was just in time to see it pop down a large rabbit-hole under the hedge.  in another moment down went alice after it, never once considering how in the world she was to get out again.  suddenly she came upon a heap of sticks and dry leaves, and the fall was over.  alice was not a moment to be lost: away went alice to herself, ‘after such a fall as this, i shall think nothing of tumbling down stairs! how brave they’ll all think me at home! why, i wouldn’t say anything about it, even if
#
#
# alice to herself, ‘after such a fall as this, i shall think nothing of tumbling down stairs! how brave they’ll all think me at home! why, i wouldn’t say anything about it, even if i fell off the top of the doors of the hall; but, alas! either the locks were too large, or the key and went on saying to herself, in a dreamy sort of way, ‘do cats eat bats? do cats eat bats, i wonder?’ and here alice began to get rather sleepy, and went on saying to herself, in a dreamy sort of way, ‘do cats
#
#
# alice, get out again.  suddenly she came upon a heap of sticks and dry leaves, and the fall was over.  alice was not a moment to be lost: away went alice to herself, ‘after such a fall as this, i shall think nothing of tumbling down stairs! how brave they’ll all think me at home! why, i wouldn’t say anything about it, even if i fell off the top of the doors of the hall; but, alas! either the locks were too large, or the key and went on saying to herself, in a dreamy sort of way,
#
#
# brave they’ll and when she had tired herself so severely as to bring tears into her eyes; and once she remembered trying to box her own ears for having cheated herself in a game of croquet she was playing against herself, for this curious child was very fond the rabbit that she was now only ten inches high, and her face brightened up at the thought it pop down a large rabbit-hole under the hedge.  in another moment down went alice after it, never once considering how in the world she was to get out again.  suddenly she
#
#
# this generally happens when she was coming to, but it was too dark to see anything; then she looked at the sides of the hall; but, alas! either the locks were too large, or the key and went on saying to herself, in a dreamy sort of way, ‘do cats eat bats? do cats eat bats, i wonder?’ and here alice began to get rather sleepy, and went on saying to herself, in a dreamy sort of way, ‘do cats eat bats? do cats eat bats, i wonder?’ and here alice began to get rather sleepy, and went on saying
#
#
# that she ought to have wondered at this, but at the time was too dark to see anything; then she looked at the sides of the hall; but, alas! either the locks were too large, or the key and went on saying to herself, in a dreamy sort of way, ‘do cats eat bats? do cats eat bats, i wonder?’ and here alice began to get rather sleepy, and went on saying to herself, in a dreamy sort of way, ‘do cats eat bats? do cats eat bats, i wonder?’ and here alice began to get rather sleepy, and went
#
#
# that, if you drink much from a bottle marked ‘poison,’ so alice ventured to taste it, and finding it very nice, (it had, in fact, a sort of mixed flavour of cherry-tart, custard, pine-apple, roast turkey, toffee, and hot buttered toast,) she very seldom followed it), and sometimes she scolded herself so severely as to bring tears into her eyes; and once she remembered trying to box her own ears for having cheated herself in a game of croquet she was playing against herself, for this curious child was very fond the rabbit that she was now only ten inches

# %% [markdown]
# ### Inline Question: Play around with different settings to get better understanding of its behavior and describe your observation. Make sure at least you cover the following points:
# * Vanilla RNN vs LSTM (you can set different time steps and test with longer texts.)
# * Problems in these approaches (there's no unique answer. just explain your own opinion from experiments.)
# #### Ans:
#
# - Vanilla RNN converges faster than LSTM with the same parameters in terms of the training accuracy but LSTM has better memory.
# - LSTM keeps the context longer, i.e. the context of the sentences are consistent but less accurate.
# - LSTM takes longer to train.
# - The problems in these approaches include; hyper-parameters tuning is required.
# - There is no good way/criteria of comparing the results of different structures, i.e. relying just on the training accuracy is not so accurate.
# - The other problem is that these models do not care about the sentence length, which is good for training but when we are generating sentences, it is not good, for example sentence starting with Alice and length 2 is better to be "Alice !" but legth 3 is better to be "Alice is here". but these models give for example "Alice is" and "Alice is here" respectively.
